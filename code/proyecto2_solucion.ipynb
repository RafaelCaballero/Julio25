# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelCaballero/Julio24/blob/main/code/proyecto2_solucion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Curso Python – Proyecto 2
# El siguiente fichero contiene datos de diferentes vinos
# "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/wines_SPA.csv"
#
# 1) Cargar el fichero y dejarlo en un dataframe df

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/wines_SPA.csv"
df = pd.read_csv(url)

df
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# ...

# %% [markdown]
# 2) ¿Cuántas filas y columnas tiene?

# %%
x, y = df.shape
print(f"Datataframe con {x} filas y {y} columnas")
# Out:
# Datataframe con 7500 filas y 11 columnas

# %% [markdown]
# 3) Escribir instrucciones para ver datos básicos del dataframe. En particular nos interesa determinar ¿hay nulos en alguna columna? ¿cuál es el precio del vino más caro? ¿y del más barato?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   winery       7500 non-null   object
#  1   wine         7500 non-null   object
#  2   year         7498 non-null   object
#  3   rating       7500 non-null   float64
#  4   num_reviews  7500 non-null   int64
#  5   country      7500 non-null   object
#  6   region       7500 non-null   object
#  7   price        7500 non-null   float64
#  8   type         6955 non-null   object
#  9   body         6331 non-null   float64
#  10  acidity      6331 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 644.7+ KB

# %%
resumen = df.describe()
resumen
# Out:
#             rating   num_reviews        price         body      acidity
# count  7500.000000   7500.000000  7500.000000  6331.000000  6331.000000
# mean      4.254933    451.109067    60.095822     4.158427     2.946612
# std       0.118029    723.001856   150.356676     0.583352     0.248202
# min       4.200000     25.000000     4.990000     2.000000     1.000000
# 25%       4.200000    389.000000    18.900000     4.000000     3.000000
# 50%       4.200000    404.000000    28.530000     4.000000     3.000000
# 75%       4.200000    415.000000    51.350000     5.000000     3.000000
# max       4.900000  32624.000000  3119.080000     5.000000     3.000000

# %%
resumen = df.describe()
barato = resumen.loc["min","price"]
caro = resumen.loc["max","price"]
print(f"El vino más barato cuesta {barato} euros, y el más caro {caro}")
# Out:
# El vino más barato cuesta 4.99 euros, y el más caro 3119.08

# %%
barato = df.price.min()
caro = df.price.max()
print(f"El vino más barato cuesta {barato} euros, y el más caro {caro}")
# Out:
# El vino más barato cuesta 4.99 euros, y el más caro 3119.08

# %% [markdown]
# 4) Mostrar solo la columna type

# %%
df.type
# Out:
# 0                   Toro Red
# 1                Tempranillo
# 2       Ribera Del Duero Red
# 3       Ribera Del Duero Red
# 4       Ribera Del Duero Red
#                 ...
# 7495               Rioja Red
# 7496             Priorat Red
# 7497                     Red
# 7498    Ribera Del Duero Red
# 7499    Ribera Del Duero Red
# Name: type, Length: 7500, dtype: object

# %%
df["type"]
# Out:
# 0                   Toro Red
# 1                Tempranillo
# 2       Ribera Del Duero Red
# 3       Ribera Del Duero Red
# 4       Ribera Del Duero Red
#                 ...
# 7495               Rioja Red
# 7496             Priorat Red
# 7497                     Red
# 7498    Ribera Del Duero Red
# 7499    Ribera Del Duero Red
# Name: type, Length: 7500, dtype: object

# %%
df[ ["type"] ]
# Out:
#                       type
# 0                 Toro Red
# 1              Tempranillo
# 2     Ribera Del Duero Red
# 3     Ribera Del Duero Red
# 4     Ribera Del Duero Red
# ...                    ...
# 7495             Rioja Red
# 7496           Priorat Red
# 7497                   Red
# 7498  Ribera Del Duero Red
# 7499  Ribera Del Duero Red
#
# [7500 rows x 1 columns]

# %%
df.loc[ : , ["type"] ]
# Out:
#                       type
# 0                 Toro Red
# 1              Tempranillo
# 2     Ribera Del Duero Red
# 3     Ribera Del Duero Red
# 4     Ribera Del Duero Red
# ...                    ...
# 7495             Rioja Red
# 7496           Priorat Red
# 7497                   Red
# 7498  Ribera Del Duero Red
# 7499  Ribera Del Duero Red
#
# [7500 rows x 1 columns]

# %% [markdown]
# 5) Mostrar solo las columnas type y body

# %%
df[ ["type","body"] ]
# Out:
#                       type  body
# 0                 Toro Red   5.0
# 1              Tempranillo   4.0
# 2     Ribera Del Duero Red   5.0
# 3     Ribera Del Duero Red   5.0
# 4     Ribera Del Duero Red   5.0
# ...                    ...   ...
# 7495             Rioja Red   4.0
# 7496           Priorat Red   4.0
# 7497                   Red   4.0
# 7498  Ribera Del Duero Red   5.0
# 7499  Ribera Del Duero Red   5.0
#
# [7500 rows x 2 columns]

# %% [markdown]
# 6) Mostrar solo el vino que ocupa la 5ª posición en el dataframe

# %%
df.iloc[4]
# Out:
# winery                 Vega Sicilia
# wine                          Unico
# year                           1996
# rating                          4.8
# num_reviews                    1309
# country                      Espana
# region             Ribera del Duero
# price                        778.06
# type           Ribera Del Duero Red
# body                            5.0
# acidity                         3.0
# Name: 4, dtype: object

# %% [markdown]
# 7) Obtener los valores diferentes de la columna `region` y la frecuencia de cada uno de ellos

# %%
df.region.unique()
# Out:
# array(['Toro', 'Vino de Espana', 'Ribera del Duero', 'Montilla-Moriles',
#        'Jumilla', 'Jerez-Xeres-Sherry', 'Priorato', 'Rioja', 'Bierzo',
#        'Castilla y Leon', 'Campo de Borja', 'Cadiz', 'Cava',
#        'Jerez Palo Cortado', 'Manzanilla', 'Valdeorras', 'Emporda',
#        'Rioja Alta', 'Alicante', 'Somontano', 'Dominio de Valdepusa',
#        'Ribeiro', 'Mallorca', 'Yecla', 'Cigales', 'Utiel-Requena',
#        'Navarra', 'Rioja Alavesa', 'Costers del Segre', 'Sardon de Duero',
#        'Malaga', 'Cataluna', 'Rueda', 'Jerez Pedro Ximenes (PX)',
#        'Montsant', 'Conca de Barbera', 'Rias Baixas', 'Jerez Amontillado',
#        'Tierra del Vino de Zamora', 'Penedes', 'Dehesa del Carrizal',
#        'Madrid', 'Carinena', 'Condado de Huelva', 'Almansa',
#        'Jerez Cream', 'Valencia', 'Sierras de Malaga', 'Ribeira Sacra',
#        'El Terrerazo', 'Jerez Oloroso', 'Castilla', 'Alella',
#        'Pla i Llevant', 'Pla de Bages', 'Pago Calzadilla', 'Andalucia',
# ...

# %%
pd.DataFrame(df.region.unique(),columns=["region"])
# Out:
#               region
# 0               Toro
# 1     Vino de Espana
# 2   Ribera del Duero
# 3   Montilla-Moriles
# 4            Jumilla
# ..               ...
# 71          Mentrida
# 72        Terra Alta
# 73           Arribes
# 74      Gran Canaria
# 75             Abona
#
# [76 rows x 1 columns]

# %%
frecuencias = df.region.value_counts()
print(type(frecuencias))
frecuencias
# Out:
# <class 'pandas.core.series.Series'>
# region
# Rioja                              2440
# Ribera del Duero                   1413
# Priorato                            686
# Toro                                300
# Vino de Espana                      263
#                                    ...
# Ribera del Gallego-Cinco Villas       1
# Monterrei                             1
# Jerez Cream                           1
# Condado de Huelva                     1
# Abona                                 1
# Name: count, Length: 76, dtype: int64

# %%
frecuencias.index[0]
# Out:
# 'Rioja'

# %% [markdown]
# 9) ¿Cuál es el valor máximo de la columna rating?

# %%
df.rating.max()
# Out:
# 4.9

# %% [markdown]
# 10) ¿Qué vinos (wine y winery) tienen esa nota?

# %%
df.rating
# Out:
# 0       4.9
# 1       4.9
# 2       4.8
# 3       4.8
# 4       4.8
#        ...
# 7495    4.2
# 7496    4.2
# 7497    4.2
# 7498    4.2
# 7499    4.2
# Name: rating, Length: 7500, dtype: float64

# %%
filtro = (df.rating  == 4.9)
df[filtro]
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
#
#            region  price         type  body  acidity
# 0            Toro  995.0     Toro Red   5.0      3.0
# 1  Vino de Espana  313.5  Tempranillo   4.0      2.0

# %%
filtro = (df.region  == "Toro")
df[filtro]
# Out:
#              winery                       wine  year  rating  num_reviews  \
# 0     Teso La Monja                      Tinto  2013     4.9           58
# 30          Ordonez  Vatan Arena Tinta de Toro  2014     4.8           79
# 35    Teso La Monja                      Tinto  2012     4.8           56
# 37    Teso La Monja                      Tinto  2009     4.8           50
# 40    Teso La Monja                      Tinto  2011     4.8           32
# ...             ...                        ...   ...     ...          ...
# 7392          Matsu                   El Viejo  2019     4.2          400
# 7417          Matsu                   El Viejo  2019     4.2          400
# 7442          Matsu                   El Viejo  2019     4.2          400
# 7467          Matsu                   El Viejo  2019     4.2          400
# 7492          Matsu                   El Viejo  2019     4.2          400
#
#      country region    price      type  body  acidity
# ...

# %% [markdown]
# 11) Generar un nuevo dataframe df2 solo con los vinos que cuestan (price) menos de 30 euros

# %%
filtro = df.price  < 30
df_baratos = df[ filtro  ]
df_baratos.to_excel("baratos.xlsx",index=False)
df_baratos
# Out:
#                                          winery  \
# 294                                    La Legua
# 300   Bodegas 6o Elemento - Vino Sexto Elemento
# 303                              Casal de Arman
# 312                          Pago de Larrainzar
# 334   Bodegas 6o Elemento - Vino Sexto Elemento
# ...                                         ...
# 7491                               Ramon Bilbao
# 7492                                      Matsu
# 7495                                    Contino
# 7496                       Conreria d'Scala Dei
# 7497                                Mustiguillo
#
#                                   wine  year  rating  num_reviews country  \
# 294                           Capricho  2014     4.6           47  Espana
# 300                            Respeto  2015     4.6           45  Espana
# 303   Finca Misenhora Edicion Limitada  2018     4.6           44  Espana
# 312               Rosado de Larrainzar  2020     4.6           39  Espana
# ...

# %% [markdown]
# 12 ¿Cuántas filas tiene?

# %%
filas, c = df_baratos.shape
filas
# Out:
# 51

# %% [markdown]
# 13) Difícil: Mostrar solo los vinos más caros. Idea: investigar acerca de la función de pandas sort_values para ordenar por price, y luego mostrar las 5 primeras

# %%
df2 =df.sort_values(by='price', ascending=False)
df2.iloc[:5]
# Out:
#                            winery                            wine  year  \
# 338  Descendientes de J. Palacios    La Faraona Bierzo (Corullon)  2010
# 196                  Vega Sicilia                           Unico  1965
# 115              Bodega Numanthia                      Termanthia  2004
# 343               Alvaro Palacios  L'Ermita Velles Vinyes Priorat  2011
# 280               Alvaro Palacios  L'Ermita Velles Vinyes Priorat  2010
#
#      rating  num_reviews country            region    price  \
# 338     4.6           28  Espana            Bierzo  3119.08
# 196     4.6          218  Espana  Ribera del Duero  2884.04
# 115     4.7          108  Espana              Toro  2814.16
# 343     4.6           27  Espana          Priorato  2750.00
# 280     4.6           60  Espana          Priorato  2750.00
#
#                      type  body  acidity
# 338                   Red   4.0      3.0
# 196  Ribera Del Duero Red   5.0      3.0
# 115              Toro Red   5.0      3.0
# ...

# %%
# %%timeit
df2.head(5)
# Out:
# 24.3 µs ± 4.97 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
df2.iloc[:5]
# Out:
# 22.5 µs ± 3.85 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
