# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelCaballero/Julio25/blob/main/code/06ejemplodataframes_resuelto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a la ciencia de datos con Python
# ###  Rafa Caballero
#
# # Caso práctico: análisis básico de datos, gráficos con pandas
#
# Comenzando cargando y preparando los datos con los que vamos a trabajar

# %%
import yfinance as yf
import pandas as pd

# Lista de tickers:
valores = ["inditex","iberdrola", "santander", "BBVA", "naturgy"]
tickers = ['ITX.MC', 'IBE.MC',    'SAN.MC', 'BBVA.MC', 'NTGY.MC']

# Fechas de inicio y fin
start_date = '2025-01-01'
end_date = '2025-07-02'

# Descargar los datos de Yahoo Finance
data = yf.download(tickers, start=start_date, end=end_date, group_by='ticker')

# Crear un DataFrame vacío para almacenar los valores OPEN
open_data = pd.DataFrame()

# Extraer los valores OPEN de cada ticker y añadirlos al DataFrame
for i,ticker in enumerate(tickers):
    open_data[valores[i]] = data[ticker]['Open']


# incremento en porcentaje con respecto al día anterior
roi = open_data.pct_change()*100

# añadimos el día de la semana
roi['dia_semana'] = roi.index.to_series().dt.day_name()

# mejor en castellano
days_translation = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}
roi['dia_semana'] = roi['dia_semana'].map(days_translation)

# Establecer el índice como una versión formateada de la fecha
roi.index = pd.to_datetime(open_data.index).strftime('%Y-%m-%d')


roi.style.background_gradient(cmap='RdYlGn')
# Out:
# /tmp/ipython-input-2-2329346569.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date, group_by='ticker')
# [*********************100%***********************]  5 of 5 completed
# <style type="text/css">
# #T_14f1d_row0_col0, #T_14f1d_row0_col1, #T_14f1d_row0_col2, #T_14f1d_row0_col3, #T_14f1d_row0_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_14f1d_row1_col0, #T_14f1d_row12_col1, #T_14f1d_row16_col3, #T_14f1d_row23_col1, #T_14f1d_row77_col3, #T_14f1d_row83_col0, #T_14f1d_row99_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_14f1d_row1_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_14f1d_row1_col2, #T_14f1d_row15_col2, #T_14f1d_row27_col0, #T_14f1d_row35_col2, #T_14f1d_row43_col3, #T_14f1d_row58_col3, #T_14f1d_row103_col2, #T_14f1d_row111_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_14f1d_row1_col3, #T_14f1d_row46_col0 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_14f1d_row1_col4, #T_14f1d_row38_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_14f1d_row2_col0, #T_14f1d_row4_col2, #T_14f1d_row9_col2, #T_14f1d_row13_col4, #T_14f1d_row23_col2, #T_14f1d_row37_col3, #T_14f1d_row47_col3, #T_14f1d_row69_col4, #T_14f1d_row99_col4, #T_14f1d_row101_col3, #T_14f1d_row124_col2 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_14f1d_row2_col1, #T_14f1d_row10_col4, #T_14f1d_row85_col1, #T_14f1d_row103_col1 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_14f1d_row2_col2, #T_14f1d_row32_col2, #T_14f1d_row40_col0, #T_14f1d_row58_col4, #T_14f1d_row75_col2, #T_14f1d_row93_col2, #T_14f1d_row98_col0, #T_14f1d_row101_col2, #T_14f1d_row114_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T
{
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_14f1d_row10_col2, #T_14f1d_row10_col3, #T_14f1d_row13_col1, #T_14f1d_row34_col3, #T_14f1d_row44_col1, #T_14f1d_row55_col3, #T_14f1d_row59_col2, #T_14f1d_row72_col2, #T_14f1d_row73_col0, #T_14f1d_row80_col2, #T_14f1d_row84_col4, #T_14f1d_row89_col4, #T_14f1d_row105_col0, #T_14f1d_row121_col4 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_14f1d_row11_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_14f1d_row11_col1, #T_14f1d_row35_col1, #T_14f1d_row83_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_14f1d_row11_col2, #T_14f1d_row29_col1, #T_14f1d_row36_col2, #T_14f1d_row38_col3, #T_14f1d_row52_col0, #T_14f1d_row63_col3, #T_14f1d_row90_col4, #T_1

# %% [markdown]
# **Ejercicio**
#
# La primera fila tiene valores NaN porque no existe fila anterior. Generar un nuevo dataframe "roi2" que sea igual que "roi" pero quitando la primera fila (idea: usar `roi.iloc[fila]` para seleccionar todo menos la primera fila)

# %%
# solución
roi2 = roi.drop(["2025-01-02"],axis=0)
roi2 = roi.iloc[1:]
# para probar
roi2.style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_c578e_row0_col0, #T_c578e_row11_col1, #T_c578e_row15_col3, #T_c578e_row22_col1, #T_c578e_row76_col3, #T_c578e_row82_col0, #T_c578e_row98_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_c578e_row0_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_c578e_row0_col2, #T_c578e_row14_col2, #T_c578e_row26_col0, #T_c578e_row34_col2, #T_c578e_row42_col3, #T_c578e_row57_col3, #T_c578e_row102_col2, #T_c578e_row110_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_c578e_row0_col3, #T_c578e_row45_col0 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_c578e_row0_col4, #T_c578e_row37_col1 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_c578e_row1_col0, #T_c578e_row3_col2, #T_c578e_row8_col2, #T_c578e_row12_col4, #T_c578e_row22_col2, #T_c578e_row36_col3, #T_c578e_row46_col3, #T_c578e_row68_col4, #T_c578e_row98_col4, #T_c578e_row100_col3, #T_c578e_row123_col2 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_c578e_row1_col1, #T_c578e_row9_col4, #T_c578e_row84_col1, #T_c578e_row102_col1 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_c578e_row1_col2, #T_c578e_row31_col2, #T_c578e_row39_col0, #T_c578e_row57_col4, #T_c578e_row74_col2, #T_c578e_row92_col2, #T_c578e_row97_col0, #T_c578e_row100_col2, #T_c578e_row113_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_c578e_row1_col3, #T_c578e_row14_col0, #T_c578e_row17_col2, #T_c578e_row22_col0, #T_c578e_row62_col0, #T_c578e_row73_col3, #T_c578e_row82_col4, #T_c578e_row90_col2, #T_c578e_row97_col2, #T_c578e_row99_col4, #T_c578e_row114_col3, #T_c578e_row120_col2 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_c578e_row1_col4, #T_c578e_row8_col1, #T_c578e_row20_col4, #T_c578e_row49_col4, #T_c578e_row85_col1 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_c578e_row2_col0, #T_c578e_row11_col0, #T_c578e_row25_col2, #T_c578e_row26_col1, #T_c578e_row28_col2, #T_c578e_row40_col4, #T_c578e_row46_col0, #T_c578e_row62_col4, #T_c578e_row110_col4 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_c578e_row2_col1, #T_c578e_row78_col4, #T_c578e_row84_col4, #T_c578e_row92_col4, #T_c578e_row93_col4, #T_c578e_row108_col4 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_c578e_row2_col2, #T_c578e_row3_col0, #T_c578e_row8_col0, #T_c578e_row14_col1, #T_c578e_row29_col3, #T_c578e_row36_col4, #T_c578e_row37_col4, #T_c578e_row44_col2, #T_c578e_row68_col1, #T_c578e_row77_col3, #T_c578e_row83_col2, #T_c578e_row84_col0, #T_c578e_row103_col0, #T_c578e_row116_col1, #T_c578e_row122_col4 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_c578e_row2_col3, #T_c578e_row5_col0, #T_c578e_row31_col1, #T_c578e_row89_col0, #T_c578e_row123_col0, #T_c578e_row123_col1 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_c578e_row2_col4, #T_c578e_row27_col2, #T_c578e_row40_col2, #T_c578e_row42_col1, #T_c578e_row45_col3, #T_c578e_row85_col2, #T_c578e_row96_col2, #T_c578e_row116_col3 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_c578e_row3_col1, #T_c578e_row5_col2, #T_c578e_row18_col2, #T_c578e_row46_col2, #T_c578e_row67_col0, #T_c578e_row95_col2, #T_c578e_row105_col0, #T_c578e_row114_col0, #T_c578e_row122_col0 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_c578e_row3_col3, #T_c578e_row7_col2, #T_c578e_row39_col2, #T_c578e_row48_col4, #T_c578e_row52_col2, #T_c578e_row77_col2 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_c578e_row3_col4, #T_c578e_row5_col3, #T_c578e_row24_col0, #T_c578e_row56_col0, #T_c578e_row58_col3, #T_c578e_row80_col2, #T_c578e_row80_col3, #T_c578e_row90_col3, #T_c578e_row90_col4, #T_c578e_row96_col0, #T_c578e_row100_col0, #T_c578e_row100_col1, #T_c578e_row102_col0, #T_c578e_row113_col1 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_c578e_row4_col0, #T_c578e_row4_col2, #T_c578e_row45_col2, #T_c578e_row48_col3, #T_c578e_row82_col2, #T_c578e_row111_col0, #T_c578e_row112_col3 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_c578e_row4_col1, #T_c578e_row27_col1, #T_c578e_row54_col0, #T_c578e_row55_col1, #T_c578e_row65_col4 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_c578e_row4_col3, #T_c578e_row10_col3, #T_c578e_row12_col3, #T_c578e_row14_col3, #T_c578e_row26_col2, #T_c578e_row40_col0, #T_c578e_row43_col3, #T_c578e_row117_col2 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_c578e_row4_col4, #T_c578e_row15_col2, #T_c578e_row17_col4, #T_c578e_row56_col3, #T_c578e_row62_col1, #T_c578e_row76_col2, #T_c578e_row87_col0, #T_c578e_row119_col3 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_c578e_row5_col1, #T_c578e_row27_col3, #T_c578e_row44_col0, #T_c578e_row44_col1, #T_c578e_row82_col3, #T_c578e_row115_col3 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_c578e_row5_col4, #T_c578e_row78_col1, #T_c578e_row104_col1, #T_c578e_row117_col4 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_c578e_row6_col0, #T_c578e_row110_col0 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_c578e_row6_col1, #T_c578e_row67_col1 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_c578e_row6_col2, #T_c578e_row20_col3, #T_c578e_row25_col1, #T_c578e_row48_col2, #T_c578e_row53_col3, #T_c578e_row96_col3, #T_c578e_row124_col3 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_c578e_row6_col3, #T_c578e_row13_col2, #T_c578e_row16_col0, #T_c578e_row28_col4, #T_c578e_row44_col4, #T_c578e_row49_col2, #T_c578e_row60_col2, #T_c578e_row77_col0, #T_c578e_row80_col0, #T_c578e_row87_col4, #T_c578e_row110_col3 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_c578e_row6_col4 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_c578e_row7_col0, #T_c578e_row13_col0, #T_c578e_row16_col2, #T_c578e_row30_col2, #T_c578e_row30_col3, #T_c578e_row47_col0, #T_c578e_row61_col0, #T_c578e_row65_col3, #T_c578e_row83_col3, #T_c578e_row103_col3, #T_c578e_row111_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_c578e_row7_col1, #T_c578e_row45_col1, #T_c578e_row52_col1, #T_c578e_row80_col4, #T_c578e_row99_col1, #T_c578e_row111_col1, #T_c578e_row112_col4 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_c578e_row7_col3, #T_c578e_row22_col3, #T_c578e_row44_col3, #T_c578e_row51_col3 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_c578e_row7_col4, #T_c578e_row80_col1 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_c578e_row8_col3, #T_c578e_row17_col0, #T_c578e_row21_col1, #T_c578e_row54_col2, #T_c578e_row63_col2, #T_c578e_row72_col2, #T_c578e_row88_col3, #T_c578e_row89_col2, #T_c578e_row89_col3, #T_c578e_row91_col2, #T_c578e_row93_col3, #T_c578e_row94_col2, #T_c578e_row94_col3, #T_c578e_row100_col4, #T_c578e_row104_col2, #T_c578e_row105_col4, #T_c578e_row107_col0 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_c578e_row8_col4, #T_c578e_row32_col1, #T_c578e_row39_col1, #T_c578e_row61_col4, #T_c578e_row86_col1, #T_c578e_row90_col0, #T_c578e_row94_col4, #T_c578e_row103_col4, #T_c578e_row111_col4, #T_c578e_row122_col1, #T_c578e_row124_col1 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_c578e_row9_col0 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_c578e_row9_col1, #T_c578e_row27_col4, #T_c578e_row59_col1, #T_c578e_row94_col1 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_c578e_row9_col2, #T_c578e_row9_col3, #T_c578e_row12_col1, #T_c578e_row33_col3, #T_c578e_row43_col1, #T_c578e_row54_col3, #T_c578e_row58_col2, #T_c578e_row71_col2, #T_c578e_row72_col0, #T_c578e_row79_col2, #T_c578e_row83_col4, #T_c578e_row88_col4, #T_c578e_row104_col0, #T_c578e_row120_col4 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_c578e_row10_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_c578e_row10_col1, #T_c578e_row34_col1, #T_c578e_row82_col1 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_c578e_row10_col2, #T_c578e_row28_col1, #T_c578e_row35_col2, #T_c578e_row37_col3, #T_c578e_row51_col0, #T_c578e_row62_col3, #T_c578e_row89_col4, #T_c578e_row97_col3, #T_c578e_row98_col2, #T_c578e_row108_col3, #T_c578e_row109_col2, #T_c578e_row117_col0, #T_c578e_row121_col1, #T_c578e_row124_col2 {
#   backgr

# %% [markdown]
# **Ejercicio**
#
# Queremos obtener el valor de BBVA el 2025-04-07 (ayuda: utilizar `roi2.loc[fila,columna]`)

# %%
# solución

# %% [markdown]
# **Ejercicio**
#
# ¿Y si queremos mostrar toda la fila correspondiente a esta fecha?

# %%
# solución

# %% [markdown]
# ### Información básica
#
# **Ejercicio**
#
# Llamar primeroa `info()`y luego a `describe()` sobre `roi2`y extraer las consecuencias adecuadas

# %% [markdown]
# **Ejercicio**
# Como se puede ver no muestra información sobre la columna "dia_semana" por no ser numérica. En estos casos se suele comprobar los valores que tiene y su frecuencia, con `unique`y `value_counts`

# %% [markdown]
# ### Gráficos sencillos con Pandas
#
# Unos histogramas burdos pero rápidos de las columnas numéricas

# %%
roi2.hist()

# %% [markdown]
# Un poquito mejor

# %%
import matplotlib.pyplot as plt

roi2.hist()
plt.tight_layout() # plt controla como se muestran los gráficos

# %% [markdown]
# Los boxplots dan otra perspectiva

# %%
roi2.boxplot()

# %% [markdown]
# Probamos un gráfico de líneas

# %%
roi2.plot()

# %% [markdown]
# uff...no se ve nada...ajustemos un poco el gráfico

# %%
roi2.index = pd.to_datetime(roi2.index)

# %%
fig, eje = plt.subplots(figsize=(20, 4))
# hacemos el gráfico, ahora le indicamos la proporción ancho y alto, además del título
roi2.plot(ax=eje, title='Evolución de los valores OPEN')
# Configurar etiquetas del eje X para mostrar 1 de cada 5 fechas
tick_positions = roi2.index[::5]
eje.set_xticks(tick_positions)
#ax.set_xticklabels(tick_positions.strftime('%Y-%m-%d'), rotation=45)
# lo grabamos en un fichero con alta resolución
fig.savefig('evolucion_open.pdf', format='pdf', dpi=300)

# %% [markdown]
# Con una función:

# %%
def gráfica(df,nombreSalida,pasoDias=5):
  fig, eje = plt.subplots(figsize=(20, 4))
  df.plot(ax=eje, title='Evolución de los valores OPEN')
  # Configurar etiquetas del eje X para mostrar 1 de cada 5 fechas
  tick_positions = roi2.index[::pasoDias]
  eje.set_xticks(tick_positions)
  # lo grabamos en un fichero con alta resolución
  fig.savefig(nombreSalida, dpi=300)

# %%
gráfica(roi2,"open.pdf")

# %% [markdown]
# ¿No se vería mejor con la media móvil?

# %%
# Calcular la media móvil de 5 días
rolling_average = roi2[valores].rolling(window=5).mean()
gráfica(rolling_average,"open_rolling.pdf")

# %% [markdown]
# Puede ser que nos interese ver un día concreto en forma de barras:

# %%
roi2.loc[["2025-06-11"]].plot.bar()

# %%
open_data.plot.area()

# %%
roi2.plot.kde() # diagrama de densidad

# %%
roi2.plot.scatter(x="santander",y="BBVA")

# %%
roi2.plot.scatter(x="santander",y="inditex")

# %%
roi2[valores].corr()

# %% [markdown]
# Hay muchos más diagramas, ver aquí: https://pandas.pydata.org/docs/user_guide/visualization.html

# %% [markdown]
# #### Filtros
#
# **Ejercicio**
#
# Mostrar la media de BBVA los Viernes

# %% [markdown]
# **Ejercicio**
#
# Convertir el código anterior en una función a la que se pase:
# - El dataframe
# - El día de la semana
# - El valor bursátil.
#
# Probarla con los valores anteriores

# %% [markdown]
# **Ejercicio** Probar la función de nuevo para el BBVA pero los Lunes

# %% [markdown]
# **Ejercicio**
#
# En qué día tuvo naturgy su mayor decremento porcentual con respecto al día anterior (el valor mínimo en `roi2`). Pista: investigar `idxmin`
