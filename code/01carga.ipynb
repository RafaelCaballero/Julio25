# %% [markdown]
# # Introducción a la ciencia de datos con Python
# ###  Rafa Caballero
#
# # Caso práctico: carga de ficheros
#
#
# Puedes usar el siguiente índice para saltar a la sección adecuado
#
#
# **Índice**
#
# [Descarga de ficheros](#Descarga-de-ficheros)
#
# [APIs](#API)
#
# [Carga de ficheros CSV con Pandas](#Carga-de-ficheros-CSV-con-Pandas)
#
# [Carga de ficheros Excel con Pandas](#Carga-de-ficheros-Excel-con-Pandas)
#
# [Carga de ficheros JSON con Pandas](#Carga-de-ficheros-JSON-con-Pandas)
#
# [Extracción de información de ficheros PDF](#Carga-de-ficheros-PDF)
#
# [Extracción de tablas WEB](#Extracción-de-tablas-WEB)
#
# [Yahoo Finance](#yahoo)

# %% [markdown]
# <a name="Descarga-de-ficheros"></a>
# ### Descarga de ficheros
#
# Como veremos, en algunos casos las librerías correspondientes nos permitirán cargar directamente datos a partir de un enlace en internet. Sin embargo, en otras ocasiones tendremos que seguir dos pasos
#
#   1.- Descargar el fichero que queramos usando la librería `requests`
#
#   2.- Manipular el fichero, ya en local, mediante la librería adecuada
#
# Vamos a ver un ejemplo muy sencillo de descarga del último fichero con los datos de inflación, donde el punto 2 es en este caso una grabación del fichero como fichero local.

# %%
import requests
url = "https://www.bolsamadrid.es/docs/SBolsas/InformesSB/resumen.pdf"
nombre = "resumen.pdf"
r = requests.get(url, allow_redirects=True) # el fichero queda en la variable r
with open(nombre, 'wb') as f:
    f.write(r.content) # ahora lo grabamos localmente

print(r.status_code)

# %% [markdown]
# Se puede comprabar si el fichero se ha descargado bien comprobando el `r.status_code`, que será 200 si todo ha sido correcto.

# %%
print(r.status_code)

# %% [markdown]
# *   200: Todo ha ido bien
# *   301: La página redirige a otra; esto podemose evitarlo con `allow_redirects=True`
# *  400: El servidor no existe o el formato de algún parámetro es erróneo
# * 401: Error de autentificación
# * 403: No tenemos permisos para acceder al recurso
# * 404: El recurso no existe aunque el servidor sí
# * 503: El servidor existe pero no puede atender la demanda
#
# Por tanto el proceso ha tenido este aspecto:
#
# <img src="https://www.dataquest.io/wp-content/uploads/2019/09/api-request.svg"></img>
#
#
# Además, [requests](https://docs.python-requests.org/) permite pasar parámetros, autenticarse con user, password, descargar de forma "perezosa" para ficheros que no caben en memoria, etc.
#
# También puede utilizarse para descargar páginas html y examinarlas extrayendo información. Sin embargo, para esto es preferible utilizar librerías como `BeautifulSoup` o, si se tiene que interaccionar con la página, `Selenium`
#
# La variable devuelta por requests (llamada `r` en este ejemplo) tiene dos partes:
#
# * El mensaje de error o de éxito `r.status_code`
#
# * Los datos en sí, `r.content`
#
# La instrucción
#
# ```
#     with open(nombre, 'wb') as f:
#       f.write(r.content) # ahora lo grabamos localmente
# ```
#
# graba el contenido (que es el fichero PDF, ahora mismo localizado en memoria) en un fichero local con el nombre que incluya la variable `nombre`

# %% [markdown]
# **Ejercicio 1** Descargar el informe de mercados 2023 disponible en "https://www.bolsasymercados.es/docs/infmercado/2023/esp/Informe-Mercado-BME-2023.pdf". Grabar el fichero localmente con nombre "informe23.pdf"
#
# Mostrar el status de la descarga a ver si todo está bien

# %% [markdown]
# **Ejercicio 2** Probar a modificar la URL para que corresponda al ejercicio 2024:
#
# https://www.bolsasymercados.es/docs/infmercado/2023/esp/Informe-Mercado-BME-2024.pdf
#
# y comprobar que el status nos devuelve un error. Grabar el fichero localmente con nombre "informe22.pdf"

# %% [markdown]
# Cuando hay error no queremos que grabe nada; esto podemos evitarlo con una instrucción `if`

# %%
import requests
url = "https://www.bolsasymercados.es/docs/infmercado/2023/esp/Informe-Mercado-BME-2024.pdf"
nombre = "informe24.pdf"
r = requests.get(url, allow_redirects=True) # el fichero queda en la variable r
if r.status_code == 200:
  with open(nombre, 'wb') as f:
      f.write(r.content) # ahora lo grabamos localmente
  print("Descargado")
else:
  print(r.status_code)

# %% [markdown]
# <a name="API"></a>
# ### APIs
#
# La librería `requests` también es útil para descargar información que no está directamente en una página sino que se puede obtener a partir de una API (Application Program Interface), es decir un servicio que nos proporciona un sitio que contiene los datos utilizando una secuencia de datos bien definida (protocolo).
#
#
# **Ejemplo**
#
# En este ejempo accedemos a la API de la agencia nacional de meteorología.
#
# Para acceder necesitaremos una clave que podemos obtener [aquí](https://opendata.aemet.es/centrodedescargas/altaUsuario?)
#
# La API nos devuelve la información en dos pasos:
#
# 1º Una primera llamada a requests.get con la URL correspondiente al dato que queremos pedir (ver [aqui](https://opendata.aemet.es/dist/index.html?) una lista de posibilidades) y nuestra clave de API nos devolverá un link al fichero con datos y fichero con metadatos
#
# 2º Una segunda llamada a requests.get nos permitirá ya obtener los datos y los metadatos con los links devueltos por el paso 1. Además, en esta segunda operación no hace falta la clave de API.
#
# En el siguiente ejemplo vamos a acceder a los datos de las últimas 24 horas de la estación de Navacerrada (código 2462)

# %%
import json # para convertir string a JSON
import requests # para descargar ficheros
import pprint # para mostrar JSON en "bonito"

api_key = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJyYWZhY3JAdWNtLmVzIiwianRpIjoiODQzZThiMWItYzdmNS00NTkxLWI1NWQtYWYzYTc0Yjk1OWQ3IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE2MzEwNTQ2MDksInVzZXJJZCI6Ijg0M2U4YjFiLWM3ZjUtNDU5MS1iNTVkLWFmM2E3NGI5NTlkNyIsInJvbGUiOiIifQ.TXZIXy-nX75cjtqD3932b8zYCQt_OW72vHIBXpFS-vA"
url = "https://opendata.aemet.es/opendata/api/observacion/convencional/datos/estacion/2462"


############################### Paso 1 ##########################
querystring = {"api_key":api_key}
response = requests.get( url,  params=querystring)

# convertirmos a formato JSON para obtener los datos
respuesta = json.loads(response.text)
print("Respuesta paso 1", respuesta)

############################### Paso 2 ####################
pet_datos = requests.get(respuesta['datos'])
valores_datos = json.loads(pet_datos.text)
print("Datos: ")
pprint.pprint(valores_datos)

# para entender los datos mostramos los metadatos
pet_metadatos = requests.get(respuesta['metadatos'])
valores_metadatos = dict(json.loads(pet_metadatos.text))
print("="*50)
print("Metadatos: ")
pprint.pprint(valores_metadatos)

# %% [markdown]
# Para entender los datos podemos consultar los metadatos

# %%
# para entender los datos mostramos los metadatos
pet_metadatos = requests.get(respuesta['metadatos'])
valores_metadatos = dict(json.loads(pet_metadatos.text))
print("="*50)
print("Metadatos: ")
pprint.pprint(valores_metadatos)

# %% [markdown]
# **Ejercicio 3**
# Para obtener dos datos con esta API solo tenemos que cambiar la URL. Por ejemplo la siguiente URL nos permite obtener datos históricos de un día y estación concretos. Completar los dos pasos para obtener el resultado

# %%
url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2021-01-06T00%3A00%3A00UTC/fechafin/2021-01-08T23%3A59%3A00UTC/estacion/3194U"

############################### Paso 1 ##########################

# %% [markdown]
# <a name="Carga-de-ficheros-CSV-con-Pandas"></a>
# ### Carga de ficheros CSV con Pandas

# %% [markdown]
# [read_csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) y [read_excel](https://pythonbasics.org/read-excel/) permiten leer ficheros separados por un carácter y ficheros excel
# En ambos casos devuelven un dataframe: una tabla en Pandas que representa el conjunto de datos en memoria
#
#
# ##### read_csv
#
# El principal parámetro es la dirección donde se encuentra el fichero. Algunos parámetros comunes de read_csv
#
# - sep: el separador, por defecto “,”
# - Header: para indicar si la primera línea contiene la cabecera (por defecto True)
# - Thousands, decimal: separadores de miles y de decimales
# - encoding: codificación de caracteres. Deber ser una codificaciones estándar

# %%
import pandas as pd # normalmente pandas se renombra como pd
fichero = 'https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/madrid/contaminacionLargo.csv'
df = pd.read_csv(fichero)
df

# %%
df["NOx"].hist()

# %% [markdown]
# El resultado es un dataframe; una tabla de pandas que utilizaremos como nuestro principal almacen de datos. Si el fichero no tiene el formato adecuado, por ejemplo, por la codificación, podemos obtener un error

# %%
fichero = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/parocomunidades.csv"
df2 = pd.read_csv(fichero)

# %%
import pandas as pd
fichero = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/parocomunidades.csv"
df2 = pd.read_csv(fichero,encoding="latin1") # o cp1252
df2

# %% [markdown]
# Ver https://python.readthedocs.io/en/stable/library/codecs.html#standard-encodings para una lista completa de codificaciones

# %% [markdown]
# ##### to_csv
# La función de pandas [to_csv](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html#pandas.DataFrame.to_csv) permite grabar un dataframe en formato csv, debemos recordar 2 cosas principalmente:
# - se encuentra dentro del objeto dataframe, por eso pondremos df.to_csv, y no pd.to_csv
# - Conviene añadir el parámetro index=False para que no incluya el índice o número de línea

# %%
fichero = "parocomunidades.csv"
df2.to_csv(fichero, index=False, encoding="utf-8")

# %% [markdown]
# **Ejercicio 4**: cargar el fichero que acabamos de grabar y mostrarlo en el notebook

# %%
# solución

# %% [markdown]
# <a name="Carga-de-ficheros-Excel-con-Pandas"></a>
# ### Carga de ficheros Excel con Pandas

# %% [markdown]
# ##### read_excel
# La lectura con pd.read_excel utiliza internamente otro librería `xlrd` que habra que instalar sino está en el sistema. Este ejemplo carga un fichero con valores bursátiles

# %%
import pandas as pd
fichero='https://github.com/RafaelCaballero/tdm/raw/master/datos/raw_open.xlsx'
df = pd.read_excel(fichero)
df

# %% [markdown]
# En el caso de múltiples páginas obtendremos un vector de dataframes. En este ejemplo cargamos datos de accidentes por distritos en la ciudad de Madrid. Se trata de un "libro" excel con hojas de nombre '2009', ..., '2016'
#
# Ojo: para manejar esta posibilidad necesitaremos una versión actualizada de xlrd

# %%
#!pip install --upgrade xlrd

# %%
import pandas as pd
fichero = "https://github.com/RafaelCaballero/tdm/raw/master/datos/madrid/accidentes_madrid_2009_2016.xlsx"
df_acc = pd.read_excel(fichero,sheet_name='2016')
df_acc

# %% [markdown]
# La grabación de ficheros excel se realiza con la función de pandas to_excel, asociada al dataframe. Esta función depende a su vez de dos librerías
#
#
#     - xlwt para grabar ficheros .xls  (formato hasta Excel2003)
#     - openpyxl para ficheros .xlsx (Excel2007 o posterior).

# %%
df_acc.to_excel("accidentes.xlsx")

# %% [markdown]
# **Ejercicio 5**
# Cargar el fichero situado en https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/ciudades_ejemplo.csv
# como un dataframe Pandas, y grabarlo a continuación en formato excel.

# %%
# solución

# %% [markdown]
# <a name="Carga-de-ficheros-JSON-con-Pandas"></a>
# ### Lectura de ficheros JSON con Pandas

# %%
url = "https://ucmdrive.ucm.es/s/ZfHGwYfi2zzJgq2/download/labs_co2.json"
import pandas as pd
df = pd.read_json(url)
df

# %% [markdown]
# <a name="Carga-de-ficheros-PDF"></a>
# ### Extracción de información de ficheros PDF
#
# Este es un tema complejo porque va a depender mucho del formato del interno del PDF. En los casos más sencillos podremos extraer por ejemplo tablas de datos con el paquete tabula-py

# %%
# !pip install tabula-py
#!pip install tabulate

# %%
from tabula import read_pdf

fichero = "./resumen.pdf"

# extraer tablas del fichero
df = read_pdf(fichero,pages="all")[0]  # 0 porque nos quedamos con la primera tabla

df

# %%
df = df.iloc[1:]  # todas las filas a partir de la 1 (es decir, quitar la 0)
df

# %% [markdown]
# Ahora podemos grabar el fichero en formato CSV

# %%
df.to_csv("resumen.csv")

# %% [markdown]
# **Nota** Si queremos cargar el fichero resumen.csv debemos tener en cuenta que los separadores de miles son puntos y los de valores decimales la coma

# %%
fichero = "resumen.csv"
df = pd.read_csv(fichero, thousands='.', decimal=',')
df

# %% [markdown]
# Proximamente veremos como manipular esta información, de momento calculemos por ejemplo la media de la columna Dif

# %%
df.Dif.mean()

# %% [markdown]
# **Ejercicio 6** Grabar el fichero en formato excel, con nombre "resumen.xlsx"

# %%
# solución

# %% [markdown]
# <a name="Extracción-de-tablas-WEB"></a>
# ### Extracción de tablas WEB

# %% [markdown]
# El método `read_html`lee todas las tablas en una página web. Se devuelven como una lista Python de dataframes, para que posteriormente podamos acceder al que deseemos.

# %%
url = "https://www.ine.es/jaxiT3/Datos.htm?t=2853"
df_list = pd.read_html(url,encoding="utf-8")
df = df_list[0]
df

# %%
import requests
import pandas as pd

url = 'https://datosmacro.expansion.com/paro-epa/espana-comunidades-autonomas'
df_list = pd.read_html(url)
df = df_list[-1] # la última tabla
df

# %% [markdown]
# <a name="yahoo"></a>
# ## Yahoo Finance
#
# Esta librería nos permite acceder a Yahoo Finance, veamos como se usa y algunas de sus posibilidades
#
# ##### Instalación

# %%
# !pip install yfinance

# %% [markdown]
# ###### Descarga de datos

# %%
import yfinance as yf

# Define el símbolo de cotización de la acción
apple = 'AAPL'
microsoft = "MSFT"

# Crea un objeto Ticker para la acción
apple_data = yf.Ticker(apple)
microsoft_data = yf.Ticker(microsoft)

# Define el rango de fechas para los datos históricos
start_date = '2024-01-01'
end_date = '2024-06-30'

apple_df = apple_data.history(period='1d', start=start_date, end=end_date)
microsoft_df = microsoft_data.history(period='1d', start=start_date, end=end_date)

microsoft_df = microsoft_df.pct_change()
apple_df = apple_df.pct_change()

microsoft_df

# %% [markdown]
# ##### Gráfico sencillo

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 6)) # proporciones del gráfico

plt.plot(apple_df['Open'], label='Apple')  # Grafica la columna 'Open'
plt.plot(microsoft_df['Open'], label='Microsoft')  # Grafica la columna 'Close'
plt.title('Cotizaciones de Apertura. Inc. Apple y Microsoft')  # Título del gráfico
plt.xlabel('Fecha')  # Etiqueta del eje X
plt.ylabel('Precio de Apertura')  # Etiqueta del eje Y
plt.legend()  # Muestra la leyenda
plt.xticks(rotation=45)  # Rota las etiquetas del eje X para mejorar la legibilidad
plt.grid(True)  # Muestra una cuadrícula en el gráfico
fig.savefig("apple_microsoft.png")
plt.show()  # Muestra el gráfico

# %% [markdown]
# También podemos extraer los máximos datos posibles, sin especificar el periodo

# %%
historico_apple = apple_data.history(period="max")
historico_apple

# %%
historico_apple.reset_index(inplace=True) # convierte el índice en un campo max
historico_apple.plot(x="Date", y="Close")

# %% [markdown]
# ##### Información general

# %%
apple_info=apple_data.info
apple_info

# %%
apple_info['totalRevenue']

# %%
apple_data.dividends

# %%
apple_data.dividends.plot()

# %% [markdown]
# <a name="Color"></a>
# ## Mostrar dataframes con color
#
# Primero cargamos un dataframe con datos del IBEX

# %%
import yfinance as yf

# Define el símbolo de cotización de la acción
símbolo = '^IBEX'

# Crea un objeto Ticker para la acción
data = yf.Ticker(símbolo)

# Define el rango de fechas para los datos históricos
start_date = '2024-01-01'
end_date = '2024-06-30'

df = data.history( start=start_date, end=end_date)

df = df[["Open", "High", "Low", "Close", "Volume"]]
df
# Out:
#                                    Open          High           Low  \
# Date
# 2024-01-02 00:00:00+01:00  10161.099609  10287.900391  10122.400391
# 2024-01-03 00:00:00+01:00  10183.799805  10209.799805  10038.099609
# 2024-01-04 00:00:00+01:00  10067.500000  10190.799805  10067.500000
# 2024-01-05 00:00:00+01:00  10130.299805  10192.000000  10061.200195
# 2024-01-08 00:00:00+01:00  10140.500000  10209.000000  10079.299805
# ...                                 ...           ...           ...
# 2024-06-24 00:00:00+02:00  11051.500000  11182.599609  11040.099609
# 2024-06-25 00:00:00+02:00  11190.099609  11190.400391  11068.700195
# 2024-06-26 00:00:00+02:00  11154.700195  11170.799805  10985.799805
# 2024-06-27 00:00:00+02:00  11018.900391  11018.900391  10930.900391
# 2024-06-28 00:00:00+02:00  10990.000000  11000.200195  10913.000000
#
#                                   Close     Volume
# Date
# 2024-01-02 00:00:00+01:00  10182.099609  137052900
# 2024-01-03 00:00:00+01:00  10053.400391  136612300
# 2024-01-04 00:00:00+01:00  10182.400391  110894200
# 2024-01-05 00:00:00+01:00  10164.500000  145036200
# 2024-01-08 00:00:00+01:00  10209.000000  110110400
# ...                                 ...        ...
# 2024-06-24 00:00:00+02:00  11172.099609   98196100
# 2024-06-25 00:00:00+02:00  11118.900391   94463200
# 2024-06-26 00:00:00+02:00  11030.500000   98074600
# 2024-06-27 00:00:00+02:00  10951.500000  100880200
# 2024-06-28 00:00:00+02:00  10943.700195  119328500
#
# [126 rows x 5 columns]

# %% [markdown]
# Mostrar con mapa de colores ([aquí](https://matplotlib.org/stable/users/explain/colors/colormaps.html) una lista de mapas de color)

# %%
df.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_d8a3c_row0_col0, #T_d8a3c_row5_col0, #T_d8a3c_row24_col4, #T_d8a3c_row50_col4, #T_d8a3c_row57_col4 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_d8a3c_row0_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_d8a3c_row0_col2, #T_d8a3c_row0_col3, #T_d8a3c_row2_col3, #T_d8a3c_row37_col2, #T_d8a3c_row47_col4, #T_d8a3c_row82_col4 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_d8a3c_row0_col4, #T_d8a3c_row1_col4, #T_d8a3c_row6_col4, #T_d8a3c_row92_col4 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_d8a3c_row1_col0, #T_d8a3c_row1_col1, #T_d8a3c_row4_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_d8a3c_row1_col2, #T_d8a3c_row7_col0, #T_d8a3c_row8_col1, #T_d8a3c_row8_col3, #T_d8a3c_row9_col1, #T_d8a3c_row23_col2, #T_d8a3c_row38_col1, #T_d8a3c_row40_col0, #T_d8a3c_row44_col2, #T_d8a3c_row46_col0, #T_d8a3c_row65_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_d8a3c_row1_col3, #T_d8a3c_row2_col0, #T_d8a3c_row5_col2, #T_d8a3c_row25_col4, #T_d8a3c_row42_col1, #T_d8a3c_row44_col0, #T_d8a3c_row49_col4, #T_d8a3c_row69_col4 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_d8a3c_row2_col1, #T_d8a3c_row3_col1, #T_d8a3c_row47_col0, #T_d8a3c_row81_col4 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_d8a3c_row2_col2, #T_d8a3c_row38_col2, #T_d8a3c_row38_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_d8a3c_row2_col4, #T_d8a3c_row4_col4, #T_d8a3c_row14_col2, #T_d8a3c_row15_col0, #T_d8a3c_row15_col1, #T_d8a3c_row26_col0, #T_d8a3c_row27_col2, #T_d8a3c_row27_col4, #T_d8a3c_row30_col1, #T_d8a3c_row33_col0, #T_d8a3c_row40_col4, #T_d8a3c_row100_col4 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_d8a3c_row3_col0, #T_d8a3c_row39_col1, #T_d8a3c_row40_col3, #T_d8a3c_row45_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_d8a3c_row3_col2, #T_d8a3c_row4_col0, #T_d8a3c_row40_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_d8a3c_row3_col3, #T_d8a3c_row37_col0, #T_d8a3c_row39_col2, #T_d8a3c_row46_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_d8a3c_row3_col4, #T_d8a3c_row13_col4, #T_d8a3c_row21_col0, #T_d8a3c_row22_col2, #T_d8a3c_row54_col4 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_d8a3c_row4_col2, #T_d8a3c_row5_col1, #T_d8a3c_row37_col3, #T_d8a3c_row39_col3, #T_d8a3c_row70_col4 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_d8a3c_row4_col3, #T_d8a3c_row46_col1, #T_d8a3c_row89_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_d8a3c_row5_col3, #T_d8a3c_row23_col3, #T_d8a3c_row42_col2, #T_d8a3c_row114_col4 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_d8a3c_row5_col4, #T_d8a3c_row23_col0, #T_d8a3c_row37_col4, #T_d8a3c_row43_col2, #T_d8a3c_row44_col3, #T_d8a3c_row63_col4, #T_d8a3c_row78_col4, #T_d8a3c_row90_col4 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_d8a3c_row6_col0, #T_d8a3c_row36_col0, #T_d8a3c_row77_col4, #T_d8a3c_row86_col4, #T_d8a3c_row94_col4 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_d8a3c_row6_col1, #T_d8a3c_row20_col3, #T_d8a3c_row24_col1, #T_d8a3c_row35_col3, #T_d8a3c_row42_col0, #T_d8a3c_row44_col1, #T_d8a3c_row45_col0, #T_d8a3c_row56_col4, #T_d8a3c_row64_col4, #T_d8a3c_row72_col4, #T_d8a3c_row95_col4 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_d8a3c_row6_col2, #T_d8a3c_row9_col3, #T_d8a3c_row21_col3, #T_d8a3c_row41_col0, #T_d8a3c_row45_col1, #T_d8a3c_row93_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_d8a3c_row6_col3, #T_d8a3c_row7_col2, #T_d8a3c_row26_col4, #T_d8a3c_row28_col4, #T_d8a3c_row41_col3, #T_d8a3c_row43_col1, #T_d8a3c_row43_col3, #T_d8a3c_row71_col4 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_d8a3c_row7_col1, #T_d8a3c_row9_col2, #T_d8a3c_row21_col4, #T_d8a3c_row22_col1, #T_d8a3c_row36_col3, #T_d8a3c_row38_col0, #T_d8a3c_row43_col4, #T_d8a3c_row58_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_d8a3c_row7_col3, #T_d8a3c_row10_col0, #T_d8a3c_row25_col2, #T_d8a3c_row25_col3, #T_d8a3c_row35_col1, #T_d8a3c_row41_col4, #T_d8a3c_row42_col3, #T_d8a3c_row104_col4, #T_d8a3c_row106_col4 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_d8a3c_row7_col4, #T_d8a3c_row8_col4, #T_d8a3c_row10_col2, #T_d8a3c_row11_col4, #T_d8a3c_row12_col4, #T_d8a3c_row22_col0, #T_d8a3c_row22_col3, #T_d8a3c_row45_col4 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_d8a3c_row8_col0, #T_d8a3c_row20_col1, #T_d8a3c_row30_col4, #T_d8a3c_row59_col4, #T_d8a3c_row112_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_d8a3c_row8_col2, #T_d8a3c_row21_col1, #T_d8a3c_row23_col4, #T_d8a3c_row36_col1, #T_d8a3c_row40_col1, #T_d8a3c_row41_col1, #T_d8a3c_row52_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_d8a3c_row9_col0, #T_d8a3c_row21_col2, #T_d8a3c_row39_col0, #T_d8a3c_row48_col4, #T_d8a3c_row51_col4, #T_d8a3c_row73_col4 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_d8a3c_row9_col4, #T_d8a3c_row15_col2, #T_d8a3c_row18_col0, #T_d8a3c_row27_col3, #T_d8a3c_row31_col0, #T_d8a3c_row34_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_d8a3c_row10_col1, #T_d8a3c_row29_col3, #T_d8a3c_row35_col2, #T_d8a3c_row74_col4, #T_d8a3c_row103_col4, #T_d8a3c_row110_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_d8a3c_row10_col3, #T_d8a3c_row24_col2, #T_d8a3c_row29_col2, #T_d8a3c_row97_col4, #T_d8a3c_row98_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_d8a3c_row10_col4, #T_d8a3c_row20_col4, #T_d8a3c_row24_col0, #T_d8a3c_row55_col4, #T_d8a3c_row60_col4, #T_d8a3c_row68_col4, #T_d8a3c_row79_col4, #T_d8a3c_row113_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_d8a3c_row11_col0, #T_d8a3c_row13_col0, #T_d8a3c_row14_col0, #T_d8a3c_row17_col1, #T_d8a3c_row19_col1, #T_d8a3c_row28_col3, #T_d8a3c_row33_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_d8a3c_row11_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_d8a3c_row11_col2, #T_d8a3c_row13_col1, #T_d8a3c_row13_col2, #T_d8a3c_row20_col0, #T_d8a3c_row28_col0, #T_d8a3c_row33_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_d8a3c_row11_col3, #T_d8a3c_row34_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_d8a3c_row12_col0, #T_d8a3c_row12_col1, #T_d8a3c_row12_col2, #T_d8a3c_row13_col3, #T_d8a3c_row15_col3, #T_d8a3c_row101_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d8a3c_row12_col3, #T_d8a3c_row16_col0, #T_d8a3c_row28_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d8a3c_row14_col1, #T_d8a3c_row16_col1, #T_d8a3c_row18_col1, #T_d8a3c_row18_col3, #T_d8a3c_row32_col0, #T_d8a3c_row32_col3, #T_d8a3c_row33_col1, #T_d8a3c_row34_col2, #T_d8a3c_row121_col4, #T_d8a3c_row123_col4, #T_d8a3c_row124_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d8a3c_row14_col3, #T_d8a3c_row19_col4, #T_d8a3c_row30_col2, #T_d8a3c_row32_col4 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_d8a3c_row14_col4, #T_d8a3c_row20_col2, #T_d8a3c_row26_col2, #T_d8a3c_row31_col1, #T_d8a3c_row36_col4, #T_d8a3c_row39_col4, #T_d8a3c_row91_col4, #T_d8a3c_row111_col4, #T_d8a3c_row117_col4 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d8a3c_row15_col4, #T_d8a3c_row31_col4, #T_d8a3c_row35_col4, #T_d8a3c_row108_col4, #T_d8a3c_row116_col4, #T_d8a3c_row125_col4 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_d8a3c_row16_col2, #T_d8a3c_row18_col4, #T_d8a3c_row38_col4, #T_d8a3c_row99_col4, #T_d8a3c_row109_col4 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_d8a3c_row16_col3, #T_d8a3c_row18_col2, #T_d8a3c_row25_col0, #T_d8a3c_row25_col1, #T_d8a3c_row30_col0, #T_d8a3c_row31_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_d8a3c_row16_col4, #T_d8a3c_row33_col4, #T_d8a3c_row43_col0, #T_d8a3c_row44_col4, #T_d8a3c_row67_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_d8a3c_row17_col0, #T_d8a3c_row17_col2, #T_d8a3c_row19_col0, #T_d8a3c_row19_col2, #T_d8a3c_row29_col0, #T_d8a3c_row29_col4, #T_d8a3c_row30_col3, #T_d8a3c_row32_col1, #T_d8a3c_row32_col2, #T_d8a3c_row35_col0, #T_d8a3c_row102_col4, #T_d8a3c_row122_col4 {

# %% [markdown]
# Mostrar máximos (aquí una lista de nombres de colores)

# %%
df.style.highlight_max(color='lightgreen')
# Out:
# <style type="text/css">
# #T_2a495_row105_col4, #T_2a495_row106_col2, #T_2a495_row109_col3, #T_2a495_row110_col0, #T_2a495_row110_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2a495" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a495_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_2a495_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_2a495_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_2a495_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_2a495_level0_col4" class="col_heading level0 col4" >Volume</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a495_level0_row0" class="row_heading level0 row0" >2024-01-02 00:00:00+01:00</th>
#       <td id="T_2a495_row0_col0" class="data row0 col0" >10161.099609</td>
#       <td id="T_2a495_row0_col1" class="data row0 col1" >10287.900391</td>
#       <td id="T_2a495_row0_col2" class="data row0 col2" >10122.400391</td>
#       <td id="T_2a495_row0_col3" class="data row0 col3" >10182.099609</td>
#       <td id="T_2a495_row0_col4" class="data row0 col4" >137052900</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row1" class="row_heading level0 row1" >2024-01-03 00:00:00+01:00</th>
#       <td id="T_2a495_row1_col0" class="data row1 col0" >10183.799805</td>
#       <td id="T_2a495_row1_col1" class="data row1 col1" >10209.799805</td>
#       <td id="T_2a495_row1_col2" class="data row1 col2" >10038.099609</td>
#       <td id="T_2a495_row1_col3" class="data row1 col3" >10053.400391</td>
#       <td id="T_2a495_row1_col4" class="data row1 col4" >136612300</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row2" class="row_heading level0 row2" >2024-01-04 00:00:00+01:00</th>
#       <td id="T_2a495_row2_col0" class="data row2 col0" >10067.500000</td>
#       <td id="T_2a495_row2_col1" class="data row2 col1" >10190.799805</td>
#       <td id="T_2a495_row2_col2" class="data row2 col2" >10067.500000</td>
#       <td id="T_2a495_row2_col3" class="data row2 col3" >10182.400391</td>
#       <td id="T_2a495_row2_col4" class="data row2 col4" >110894200</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row3" class="row_heading level0 row3" >2024-01-05 00:00:00+01:00</th>
#       <td id="T_2a495_row3_col0" class="data row3 col0" >10130.299805</td>
#       <td id="T_2a495_row3_col1" class="data row3 col1" >10192.000000</td>
#       <td id="T_2a495_row3_col2" class="data row3 col2" >10061.200195</td>
#       <td id="T_2a495_row3_col3" class="data row3 col3" >10164.500000</td>
#       <td id="T_2a495_row3_col4" class="data row3 col4" >145036200</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row4" class="row_heading level0 row4" >2024-01-08 00:00:00+01:00</th>
#       <td id="T_2a495_row4_col0" class="data row4 col0" >10140.500000</td>
#       <td id="T_2a495_row4_col1" class="data row4 col1" >10209.000000</td>
#       <td id="T_2a495_row4_col2" class="data row4 col2" >10079.299805</td>
#       <td id="T_2a495_row4_col3" class="data row4 col3" >10209.000000</td>
#       <td id="T_2a495_row4_col4" class="data row4 col4" >110110400</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row5" class="row_heading level0 row5" >2024-01-09 00:00:00+01:00</th>
#       <td id="T_2a495_row5_col0" class="data row5 col0" >10159.000000</td>
#       <td id="T_2a495_row5_col1" class="data row5 col1" >10181.900391</td>
#       <td id="T_2a495_row5_col2" class="data row5 col2" >9994.000000</td>
#       <td id="T_2a495_row5_col3" class="data row5 col3" >10060.299805</td>
#       <td id="T_2a495_row5_col4" class="data row5 col4" >157192400</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row6" class="row_heading level0 row6" >2024-01-10 00:00:00+01:00</th>
#       <td id="T_2a495_row6_col0" class="data row6 col0" >10053.900391</td>
#       <td id="T_2a495_row6_col1" class="data row6 col1" >10079.799805</td>
#       <td id="T_2a495_row6_col2" class="data row6 col2" >10017.799805</td>
#       <td id="T_2a495_row6_col3" class="data row6 col3" >10067.099609</td>
#       <td id="T_2a495_row6_col4" class="data row6 col4" >136822100</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row7" class="row_heading level0 row7" >2024-01-11 00:00:00+01:00</th>
#       <td id="T_2a495_row7_col0" class="data row7 col0" >10112.700195</td>
#       <td id="T_2a495_row7_col1" class="data row7 col1" >10151.799805</td>
#       <td id="T_2a495_row7_col2" class="data row7 col2" >10004.900391</td>
#       <td id="T_2a495_row7_col3" class="data row7 col3" >10004.900391</td>
#       <td id="T_2a495_row7_col4" class="data row7 col4" >134217300</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row8" class="row_heading level0 row8" >2024-01-12 00:00:00+01:00</th>
#       <td id="T_2a495_row8_col0" class="data row8 col0" >10024.799805</td>
#       <td id="T_2a495_row8_col1" class="data row8 col1" >10134.700195</td>
#       <td id="T_2a495_row8_col2" class="data row8 col2" >10023.799805</td>
#       <td id="T_2a495_row8_col3" class="data row8 col3" >10094.799805</td>
#       <td id="T_2a495_row8_col4" class="data row8 col4" >134251900</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row9" class="row_heading level0 row9" >2024-01-15 00:00:00+01:00</th>
#       <td id="T_2a495_row9_col0" class="data row9 col0" >10118.900391</td>
#       <td id="T_2a495_row9_col1" class="data row9 col1" >10135.299805</td>
#       <td id="T_2a495_row9_col2" class="data row9 col2" >10048.599609</td>
#       <td id="T_2a495_row9_col3" class="data row9 col3" >10076.900391</td>
#       <td id="T_2a495_row9_col4" class="data row9 col4" >87931100</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row10" class="row_heading level0 row10" >2024-01-16 00:00:00+01:00</th>
#       <td id="T_2a495_row10_col0" class="data row10 col0" >10022.700195</td>
#       <td id="T_2a495_row10_col1" class="data row10 col1" >10024.299805</td>
#       <td id="T_2a495_row10_col2" class="data row10 col2" >9955.000000</td>
#       <td id="T_2a495_row10_col3" class="data row10 col3" >9994.099609</td>
#       <td id="T_2a495_row10_col4" class="data row10 col4" >138279400</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row11" class="row_heading level0 row11" >2024-01-17 00:00:00+01:00</th>
#       <td id="T_2a495_row11_col0" class="data row11 col0" >9916.799805</td>
#       <td id="T_2a495_row11_col1" class="data row11 col1" >9916.799805</td>
#       <td id="T_2a495_row11_col2" class="data row11 col2" >9826.599609</td>
#       <td id="T_2a495_row11_col3" class="data row11 col3" >9867.799805</td>
#       <td id="T_2a495_row11_col4" class="data row11 col4" >133882600</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row12" class="row_heading level0 row12" >2024-01-18 00:00:00+01:00</th>
#       <td id="T_2a495_row12_col0" class="data row12 col0" >9876.799805</td>
#       <td id="T_2a495_row12_col1" class="data row12 col1" >9901.500000</td>
#       <td id="T_2a495_row12_col2" class="data row12 col2" >9798.799805</td>
#       <td id="T_2a495_row12_col3" class="data row12 col3" >9880.299805</td>
#       <td id="T_2a495_row12_col4" class="data row12 col4" >134134100</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row13" class="row_heading level0 row13" >2024-01-19 00:00:00+01:00</th>
#       <td id="T_2a495_row13_col0" class="data row13 col0" >9915.799805</td>
#       <td id="T_2a495_row13_col1" class="data row13 col1" >9931.000000</td>
#       <td id="T_2a495_row13_col2" class="data row13 col2" >9823.700195</td>
#       <td id="T_2a495_row13_col3" class="data row13 col3" >9858.299805</td>
#       <td id="T_2a495_row13_col4" class="data row13 col4" >146590900</td>
#     </tr>
#     <tr>
#       <th id="T_2a495_level0_row14" class="row_heading level0 row14" >2024-01-22 00:00:00+01:00</th>
#       <td id="T_2a4

# %%
df.style.highlight_min(color='cyan')
# Out:
# <style type="text/css">
# #T_9f17e_row12_col0, #T_9f17e_row12_col1, #T_9f17e_row12_col2, #T_9f17e_row13_col3, #T_9f17e_row101_col4 {
#   background-color: cyan;
# }
# </style>
# <table id="T_9f17e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f17e_level0_col0" class="col_heading level0 col0" >Open</th>
#       <th id="T_9f17e_level0_col1" class="col_heading level0 col1" >High</th>
#       <th id="T_9f17e_level0_col2" class="col_heading level0 col2" >Low</th>
#       <th id="T_9f17e_level0_col3" class="col_heading level0 col3" >Close</th>
#       <th id="T_9f17e_level0_col4" class="col_heading level0 col4" >Volume</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f17e_level0_row0" class="row_heading level0 row0" >2024-01-02 00:00:00+01:00</th>
#       <td id="T_9f17e_row0_col0" class="data row0 col0" >10161.099609</td>
#       <td id="T_9f17e_row0_col1" class="data row0 col1" >10287.900391</td>
#       <td id="T_9f17e_row0_col2" class="data row0 col2" >10122.400391</td>
#       <td id="T_9f17e_row0_col3" class="data row0 col3" >10182.099609</td>
#       <td id="T_9f17e_row0_col4" class="data row0 col4" >137052900</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row1" class="row_heading level0 row1" >2024-01-03 00:00:00+01:00</th>
#       <td id="T_9f17e_row1_col0" class="data row1 col0" >10183.799805</td>
#       <td id="T_9f17e_row1_col1" class="data row1 col1" >10209.799805</td>
#       <td id="T_9f17e_row1_col2" class="data row1 col2" >10038.099609</td>
#       <td id="T_9f17e_row1_col3" class="data row1 col3" >10053.400391</td>
#       <td id="T_9f17e_row1_col4" class="data row1 col4" >136612300</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row2" class="row_heading level0 row2" >2024-01-04 00:00:00+01:00</th>
#       <td id="T_9f17e_row2_col0" class="data row2 col0" >10067.500000</td>
#       <td id="T_9f17e_row2_col1" class="data row2 col1" >10190.799805</td>
#       <td id="T_9f17e_row2_col2" class="data row2 col2" >10067.500000</td>
#       <td id="T_9f17e_row2_col3" class="data row2 col3" >10182.400391</td>
#       <td id="T_9f17e_row2_col4" class="data row2 col4" >110894200</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row3" class="row_heading level0 row3" >2024-01-05 00:00:00+01:00</th>
#       <td id="T_9f17e_row3_col0" class="data row3 col0" >10130.299805</td>
#       <td id="T_9f17e_row3_col1" class="data row3 col1" >10192.000000</td>
#       <td id="T_9f17e_row3_col2" class="data row3 col2" >10061.200195</td>
#       <td id="T_9f17e_row3_col3" class="data row3 col3" >10164.500000</td>
#       <td id="T_9f17e_row3_col4" class="data row3 col4" >145036200</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row4" class="row_heading level0 row4" >2024-01-08 00:00:00+01:00</th>
#       <td id="T_9f17e_row4_col0" class="data row4 col0" >10140.500000</td>
#       <td id="T_9f17e_row4_col1" class="data row4 col1" >10209.000000</td>
#       <td id="T_9f17e_row4_col2" class="data row4 col2" >10079.299805</td>
#       <td id="T_9f17e_row4_col3" class="data row4 col3" >10209.000000</td>
#       <td id="T_9f17e_row4_col4" class="data row4 col4" >110110400</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row5" class="row_heading level0 row5" >2024-01-09 00:00:00+01:00</th>
#       <td id="T_9f17e_row5_col0" class="data row5 col0" >10159.000000</td>
#       <td id="T_9f17e_row5_col1" class="data row5 col1" >10181.900391</td>
#       <td id="T_9f17e_row5_col2" class="data row5 col2" >9994.000000</td>
#       <td id="T_9f17e_row5_col3" class="data row5 col3" >10060.299805</td>
#       <td id="T_9f17e_row5_col4" class="data row5 col4" >157192400</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row6" class="row_heading level0 row6" >2024-01-10 00:00:00+01:00</th>
#       <td id="T_9f17e_row6_col0" class="data row6 col0" >10053.900391</td>
#       <td id="T_9f17e_row6_col1" class="data row6 col1" >10079.799805</td>
#       <td id="T_9f17e_row6_col2" class="data row6 col2" >10017.799805</td>
#       <td id="T_9f17e_row6_col3" class="data row6 col3" >10067.099609</td>
#       <td id="T_9f17e_row6_col4" class="data row6 col4" >136822100</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row7" class="row_heading level0 row7" >2024-01-11 00:00:00+01:00</th>
#       <td id="T_9f17e_row7_col0" class="data row7 col0" >10112.700195</td>
#       <td id="T_9f17e_row7_col1" class="data row7 col1" >10151.799805</td>
#       <td id="T_9f17e_row7_col2" class="data row7 col2" >10004.900391</td>
#       <td id="T_9f17e_row7_col3" class="data row7 col3" >10004.900391</td>
#       <td id="T_9f17e_row7_col4" class="data row7 col4" >134217300</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row8" class="row_heading level0 row8" >2024-01-12 00:00:00+01:00</th>
#       <td id="T_9f17e_row8_col0" class="data row8 col0" >10024.799805</td>
#       <td id="T_9f17e_row8_col1" class="data row8 col1" >10134.700195</td>
#       <td id="T_9f17e_row8_col2" class="data row8 col2" >10023.799805</td>
#       <td id="T_9f17e_row8_col3" class="data row8 col3" >10094.799805</td>
#       <td id="T_9f17e_row8_col4" class="data row8 col4" >134251900</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row9" class="row_heading level0 row9" >2024-01-15 00:00:00+01:00</th>
#       <td id="T_9f17e_row9_col0" class="data row9 col0" >10118.900391</td>
#       <td id="T_9f17e_row9_col1" class="data row9 col1" >10135.299805</td>
#       <td id="T_9f17e_row9_col2" class="data row9 col2" >10048.599609</td>
#       <td id="T_9f17e_row9_col3" class="data row9 col3" >10076.900391</td>
#       <td id="T_9f17e_row9_col4" class="data row9 col4" >87931100</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row10" class="row_heading level0 row10" >2024-01-16 00:00:00+01:00</th>
#       <td id="T_9f17e_row10_col0" class="data row10 col0" >10022.700195</td>
#       <td id="T_9f17e_row10_col1" class="data row10 col1" >10024.299805</td>
#       <td id="T_9f17e_row10_col2" class="data row10 col2" >9955.000000</td>
#       <td id="T_9f17e_row10_col3" class="data row10 col3" >9994.099609</td>
#       <td id="T_9f17e_row10_col4" class="data row10 col4" >138279400</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row11" class="row_heading level0 row11" >2024-01-17 00:00:00+01:00</th>
#       <td id="T_9f17e_row11_col0" class="data row11 col0" >9916.799805</td>
#       <td id="T_9f17e_row11_col1" class="data row11 col1" >9916.799805</td>
#       <td id="T_9f17e_row11_col2" class="data row11 col2" >9826.599609</td>
#       <td id="T_9f17e_row11_col3" class="data row11 col3" >9867.799805</td>
#       <td id="T_9f17e_row11_col4" class="data row11 col4" >133882600</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row12" class="row_heading level0 row12" >2024-01-18 00:00:00+01:00</th>
#       <td id="T_9f17e_row12_col0" class="data row12 col0" >9876.799805</td>
#       <td id="T_9f17e_row12_col1" class="data row12 col1" >9901.500000</td>
#       <td id="T_9f17e_row12_col2" class="data row12 col2" >9798.799805</td>
#       <td id="T_9f17e_row12_col3" class="data row12 col3" >9880.299805</td>
#       <td id="T_9f17e_row12_col4" class="data row12 col4" >134134100</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row13" class="row_heading level0 row13" >2024-01-19 00:00:00+01:00</th>
#       <td id="T_9f17e_row13_col0" class="data row13 col0" >9915.799805</td>
#       <td id="T_9f17e_row13_col1" class="data row13 col1" >9931.000000</td>
#       <td id="T_9f17e_row13_col2" class="data row13 col2" >9823.700195</td>
#       <td id="T_9f17e_row13_col3" class="data row13 col3" >9858.299805</td>
#       <td id="T_9f17e_row13_col4" class="data row13 col4" >146590900</td>
#     </tr>
#     <tr>
#       <th id="T_9f17e_level0_row14" class="row_heading level0 row14" >2024-01-22 00:00:00+01:00</th>
#       <td id="T_9f17e_row14_c

# %% [markdown]
# Barra de color

# %%
df.style.bar(align='left', color='wheat')
# Out:
# <style type="text/css">
# #T_99714_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 18.1%, transparent 18.1%);
# }
# #T_99714_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 24.6%, transparent 24.6%);
# }
# #T_99714_row0_col2, #T_99714_row82_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 20.5%, transparent 20.5%);
# }
# #T_99714_row0_col3, #T_99714_row2_col3, #T_99714_row37_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 20.4%, transparent 20.4%);
# }
# #T_99714_row0_col4, #T_99714_row1_col4, #T_99714_row6_col4, #T_99714_row92_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 10.5%, transparent 10.5%);
# }
# #T_99714_row1_col0, #T_99714_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 19.6%, transparent 19.6%);
# }
# #T_99714_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 19.7%, transparent 19.7%);
# }
# #T_99714_row1_col2, #T_99714_row46_col0, #T_99714_row65_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 15.2%, transparent 15.2%);
# }
# #T_99714_row1_col3, #T_99714_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 12.3%, transparent 12.3%);
# }
# #T_99714_row2_col0, #T_99714_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 12.1%, transparent 12.1%);
# }
# #T_99714_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 18.4%, transparent 18.4%);
# }
# #T_99714_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 17.0%, transparent 17.0%);
# }
# #T_99714_row2_col4, #T_99714_row26_col0, #T_99714_row30_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 6.5%, transparent 6.5%);
# }
# #T_99714_row3_col0, #T_99714_row40_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 16.1%, transparent 16.1%);
# }
# #T_99714_row3_col1, #T_99714_row47_col0, #T_99714_row81_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 18.5%, transparent 18.5%);
# }
# #T_99714_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 16.6%, transparent 16.6%);
# }
# #T_99714_row3_col3, #T_99714_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 19.3%, transparent 19.3%);
# }
# #T_99714_row3_col4, #T_99714_row54_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 11.8%, transparent 11.8%);
# }
# #T_99714_row4_col0, #T_99714_row38_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 16.8%, transparent 16.8%);
# }
# #T_99714_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 17.8%, transparent 17.8%);
# }
# #T_99714_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 22.1%, transparent 22.1%);
# }
# #T_99714_row4_col4, #T_99714_row15_col1, #T_99714_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 6.3%, transparent 6.3%);
# }
# #T_99714_row5_col0, #T_99714_row50_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 18.0%, transparent 18.0%);
# }
# #T_99714_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 17.9%, transparent 17.9%);
# }
# #T_99714_row5_col2, #T_99714_row42_col1, #T_99714_row49_col4, #T_99714_row69_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 12.4%, transparent 12.4%);
# }
# #T_99714_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 12.7%, transparent 12.7%);
# }
# #T_99714_row5_col4, #T_99714_row63_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 13.6%, transparent 13.6%);
# }
# #T_99714_row6_col0, #T_99714_row35_col3, #T_99714_row42_col0, #T_99714_row86_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 11.3%, transparent 11.3%);
# }
# #T_99714_row6_col1, #T_99714_row20_col3, #T_99714_row56_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 11.4%, transparent 11.4%);
# }
# #T_99714_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 13.9%, transparent 13.9%);
# }
# #T_99714_row6_col3, #T_99714_row26_col4, #T_99714_row43_col1, #T_99714_row71_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 13.2%, transparent 13.2%);
# }
# #T_99714_row7_col0, #T_99714_row38_col1, #T_99714_row44_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 15.0%, transparent 15.0%);
# }
# #T_99714_row7_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 16.0%, transparent 16.0%);
# }
# #T_99714_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 13.1%, transparent 13.1%);
# }
# #T_99714_row7_col3, #T_99714_row41_col4, #T_99714_row106_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 9.2%, transparent 9.2%);
# }
# #T_99714_row7_col4, #T_99714_row8_col4, #T_99714_row12_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 10.1%, transparent 10.1%);
# }
# #T_99714_row8_col0, #T_99714_row35_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 9.4%, transparent 9.4%);
# }
# #T_99714_row8_col1, #T_99714_row8_col3, #T_99714_row9_col1, #T_99714_row23_col2, #T_99714_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 14.9%, transparent 14.9%);
# }
# #T_99714_row8_col2, #T_99714_row52_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 14.2%, transparent 14.2%);
# }
# #T_99714_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 15.4%, transparent 15.4%);
# }
# #T_99714_row9_col2, #T_99714_row22_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 15.8%, transparent 15.8%);
# }
# #T_99714_row9_col3, #T_99714_row21_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 13.8%, transparent 13.8%);
# }
# #T_99714_row9_col4, #T_99714_row15_col2, #T_99714_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 2.9%, transparent 2.9%);
# }
# #T_99714_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 9.3%, transparent 9.3%);
# }
# #T_99714_row10_col1, #T_99714_row31_col4, #T_99714_row108_col4, #T_99714_row125_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 7.8%, transparent 7.8%);
# }
# #T_99714_row10_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 9.9%, transparent 9.9%);
# }
# #T_99714_row10_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 8.6%, transparent 8.6%);
# }
# #T_99714_row10_col4, #T_99714_row55_col4, #T_99714_row79_col4, #T_99714_row113_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 10.7%, transparent 10.7%);
# }
# #T_99714_row11_col0, #T_99714_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 2.5%, transparent 2.5%);
# }
# #T_99714_row11_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 1.0%, transparent 1.0%);
# }
# #T_99714_row11_col2, #T_99714_row33_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 1.8%, transparent 1.8%);
# }
# #T_99714_row11_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 0.6%, transparent 0.6%);
# }
# #T_99714_row11_col4, #T_99714_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 10.0%, transparent 10.0%);
# }
# #T_99714_row12_col0, #T_99714_row12_col1, #T_99714_row12_col2, #T_99714_row13_col3, #T_99714_row101_col4 {
#   width: 10em;
# }
# #T_99714_row12_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 1.4%, transparent 1.4%);
# }
# #T_99714_row13_col1, #T_99714_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 1.9%, transparent 1.9%);
# }
# #T_99714_row13_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 1.6%, transparent 1.6%);
# }
# #T_99714_row13_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 12.0%, transparent 12.0%);
# }
# #T_99714_row14_col0, #T_99714_row28_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 2.4%, transparent 2.4%);
# }
# #T_99714_row14_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 5.1%, transparent 5.1%);
# }
# #T_99714_row14_col2, #T_99714_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, wheat 6.6%, transparent 6.6%);
# }
# #T_99714_row14_col3, #T_99714_row30_col2, #T_99714_row32_col4 {
#   width: 10em;
#   background: l

# %% [markdown]
# Color condicional

# %%
def colorea(val):
    color = 'lightcoral' if val > df2.Open.mean() else 'lime'
    return f'background-color: {color}'

df2 = df[["Open"]]

df2.style.applymap(colorea)
# Out:
# <style type="text/css">
# #T_dabf7_row0_col0, #T_dabf7_row1_col0, #T_dabf7_row2_col0, #T_dabf7_row3_col0, #T_dabf7_row4_col0, #T_dabf7_row5_col0, #T_dabf7_row6_col0, #T_dabf7_row7_col0, #T_dabf7_row8_col0, #T_dabf7_row9_col0, #T_dabf7_row10_col0, #T_dabf7_row11_col0, #T_dabf7_row12_col0, #T_dabf7_row13_col0, #T_dabf7_row14_col0, #T_dabf7_row15_col0, #T_dabf7_row16_col0, #T_dabf7_row17_col0, #T_dabf7_row18_col0, #T_dabf7_row19_col0, #T_dabf7_row20_col0, #T_dabf7_row21_col0, #T_dabf7_row22_col0, #T_dabf7_row23_col0, #T_dabf7_row24_col0, #T_dabf7_row25_col0, #T_dabf7_row26_col0, #T_dabf7_row27_col0, #T_dabf7_row28_col0, #T_dabf7_row29_col0, #T_dabf7_row30_col0, #T_dabf7_row31_col0, #T_dabf7_row32_col0, #T_dabf7_row33_col0, #T_dabf7_row34_col0, #T_dabf7_row35_col0, #T_dabf7_row36_col0, #T_dabf7_row37_col0, #T_dabf7_row38_col0, #T_dabf7_row39_col0, #T_dabf7_row40_col0, #T_dabf7_row41_col0, #T_dabf7_row42_col0, #T_dabf7_row43_col0, #T_dabf7_row44_col0, #T_dabf7_row45_col0, #T_dabf7_row46_col0, #T_dabf7_row47_col0, #T_dabf7_row48_col0, #T_dabf7_row49_col0, #T_dabf7_row50_col0, #T_dabf7_row51_col0, #T_dabf7_row52_col0, #T_dabf7_row53_col0, #T_dabf7_row54_col0, #T_dabf7_row55_col0, #T_dabf7_row73_col0, #T_dabf7_row74_col0 {
#   background-color: lime;
# }
# #T_dabf7_row56_col0, #T_dabf7_row57_col0, #T_dabf7_row58_col0, #T_dabf7_row59_col0, #T_dabf7_row60_col0, #T_dabf7_row61_col0, #T_dabf7_row62_col0, #T_dabf7_row63_col0, #T_dabf7_row64_col0, #T_dabf7_row65_col0, #T_dabf7_row66_col0, #T_dabf7_row67_col0, #T_dabf7_row68_col0, #T_dabf7_row69_col0, #T_dabf7_row70_col0, #T_dabf7_row71_col0, #T_dabf7_row72_col0, #T_dabf7_row75_col0, #T_dabf7_row76_col0, #T_dabf7_row77_col0, #T_dabf7_row78_col0, #T_dabf7_row79_col0, #T_dabf7_row80_col0, #T_dabf7_row81_col0, #T_dabf7_row82_col0, #T_dabf7_row83_col0, #T_dabf7_row84_col0, #T_dabf7_row85_col0, #T_dabf7_row86_col0, #T_dabf7_row87_col0, #T_dabf7_row88_col0, #T_dabf7_row89_col0, #T_dabf7_row90_col0, #T_dabf7_row91_col0, #T_dabf7_row92_col0, #T_dabf7_row93_col0, #T_dabf7_row94_col0, #T_dabf7_row95_col0, #T_dabf7_row96_col0, #T_dabf7_row97_col0, #T_dabf7_row98_col0, #T_dabf7_row99_col0, #T_dabf7_row100_col0, #T_dabf7_row101_col0, #T_dabf7_row102_col0, #T_dabf7_row103_col0, #T_dabf7_row104_col0, #T_dabf7_row105_col0, #T_dabf7_row106_col0, #T_dabf7_row107_col0, #T_dabf7_row108_col0, #T_dabf7_row109_col0, #T_dabf7_row110_col0, #T_dabf7_row111_col0, #T_dabf7_row112_col0, #T_dabf7_row113_col0, #T_dabf7_row114_col0, #T_dabf7_row115_col0, #T_dabf7_row116_col0, #T_dabf7_row117_col0, #T_dabf7_row118_col0, #T_dabf7_row119_col0, #T_dabf7_row120_col0, #T_dabf7_row121_col0, #T_dabf7_row122_col0, #T_dabf7_row123_col0, #T_dabf7_row124_col0, #T_dabf7_row125_col0 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_dabf7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dabf7_level0_col0" class="col_heading level0 col0" >Open</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dabf7_level0_row0" class="row_heading level0 row0" >2024-01-02 00:00:00+01:00</th>
#       <td id="T_dabf7_row0_col0" class="data row0 col0" >10161.099609</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row1" class="row_heading level0 row1" >2024-01-03 00:00:00+01:00</th>
#       <td id="T_dabf7_row1_col0" class="data row1 col0" >10183.799805</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row2" class="row_heading level0 row2" >2024-01-04 00:00:00+01:00</th>
#       <td id="T_dabf7_row2_col0" class="data row2 col0" >10067.500000</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row3" class="row_heading level0 row3" >2024-01-05 00:00:00+01:00</th>
#       <td id="T_dabf7_row3_col0" class="data row3 col0" >10130.299805</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row4" class="row_heading level0 row4" >2024-01-08 00:00:00+01:00</th>
#       <td id="T_dabf7_row4_col0" class="data row4 col0" >10140.500000</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row5" class="row_heading level0 row5" >2024-01-09 00:00:00+01:00</th>
#       <td id="T_dabf7_row5_col0" class="data row5 col0" >10159.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row6" class="row_heading level0 row6" >2024-01-10 00:00:00+01:00</th>
#       <td id="T_dabf7_row6_col0" class="data row6 col0" >10053.900391</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row7" class="row_heading level0 row7" >2024-01-11 00:00:00+01:00</th>
#       <td id="T_dabf7_row7_col0" class="data row7 col0" >10112.700195</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row8" class="row_heading level0 row8" >2024-01-12 00:00:00+01:00</th>
#       <td id="T_dabf7_row8_col0" class="data row8 col0" >10024.799805</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row9" class="row_heading level0 row9" >2024-01-15 00:00:00+01:00</th>
#       <td id="T_dabf7_row9_col0" class="data row9 col0" >10118.900391</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row10" class="row_heading level0 row10" >2024-01-16 00:00:00+01:00</th>
#       <td id="T_dabf7_row10_col0" class="data row10 col0" >10022.700195</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row11" class="row_heading level0 row11" >2024-01-17 00:00:00+01:00</th>
#       <td id="T_dabf7_row11_col0" class="data row11 col0" >9916.799805</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row12" class="row_heading level0 row12" >2024-01-18 00:00:00+01:00</th>
#       <td id="T_dabf7_row12_col0" class="data row12 col0" >9876.799805</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row13" class="row_heading level0 row13" >2024-01-19 00:00:00+01:00</th>
#       <td id="T_dabf7_row13_col0" class="data row13 col0" >9915.799805</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row14" class="row_heading level0 row14" >2024-01-22 00:00:00+01:00</th>
#       <td id="T_dabf7_row14_col0" class="data row14 col0" >9915.200195</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row15" class="row_heading level0 row15" >2024-01-23 00:00:00+01:00</th>
#       <td id="T_dabf7_row15_col0" class="data row15 col0" >9980.500000</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row16" class="row_heading level0 row16" >2024-01-24 00:00:00+01:00</th>
#       <td id="T_dabf7_row16_col0" class="data row16 col0" >9897.900391</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row17" class="row_heading level0 row17" >2024-01-25 00:00:00+01:00</th>
#       <td id="T_dabf7_row17_col0" class="data row17 col0" >9941.700195</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row18" class="row_heading level0 row18" >2024-01-26 00:00:00+01:00</th>
#       <td id="T_dabf7_row18_col0" class="data row18 col0" >9923.500000</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row19" class="row_heading level0 row19" >2024-01-29 00:00:00+01:00</th>
#       <td id="T_dabf7_row19_col0" class="data row19 col0" >9938.299805</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row20" class="row_heading level0 row20" >2024-01-30 00:00:00+01:00</th>
#       <td id="T_dabf7_row20_col0" class="data row20 col0" >9902.900391</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row21" class="row_heading level0 row21" >2024-01-31 00:00:00+01:00</th>
#       <td id="T_dabf7_row21_col0" class="data row21 col0" >10066.200195</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row22" class="row_heading level0 row22" >2024-02-01 00:00:00+01:00</th>
#       <td id="T_dabf7_row22_col0" class="data row22 col0" >10034.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row23" class="row_heading level0 row23" >2024-02-02 00:00:00+01:00</th>
#       <td id="T_dabf7_row23_col0" class="data row23 col0" >10087.599609</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row24" class="row_heading level0 row24" >2024-02-05 00:00:00+01:00</th>
#       <td id="T_dabf7_row24_col0" class="data row24 col0" >10047.400391</td>
#     </tr>
#     <tr>
#       <th id="T_dabf7_level0_row25" cl
