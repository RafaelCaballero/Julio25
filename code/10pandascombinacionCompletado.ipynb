# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelCaballero/Julio24/blob/main/code/10pandascombinacionCompletado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a la ciencia de datos con Python
# ### Rafa Caballero
#
# ### Combinando dataframes
# Veamos en este Notebook cómo se combinan y agregan dataframes
#
# ### Índice
# [Concatenar](#Concatenar)<br>
# [Merge](#Merge)<br>

# %% [markdown]
# El siguiente código es para mostrar una dataframe al lado de otro, ejecutarlo pero no hace falta entenderlo

# %%
from IPython.display import display, HTML
from IPython.display import display_html
from IPython.display import Markdown

def display_side_by_side(*args,title=""):
    print(title)
    html_str = ''
    for df in args:
        html_str += '&nbsp;&nbsp;&nbsp;'+df.to_html()
    display_html(
        html_str.replace('table','table style="display:inline"'),
        raw=True)

# %% [markdown]
# <a name="Concatenar"></a>
# ### Concatenar
#
# La forma más fácil, y a veces la más rápida y útil, de combinar dataframes, ya sea "pegándolo" debajo o al lado con `pd.concat`
#
# <img src = "https://miro.medium.com/max/1050/1*0wu6DunCzPC4o9FIyRTW4w.png">

# %%
import IPython.display as display
import pandas as pd
from pandas import DataFrame
from random import sample


df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['e', 'e', 'e', 'e'],
                 'data': range(4),
                 'otro': sample(range(10, 30), 4)})

display_side_by_side(df1,df2)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>e</td>
#       <td>0</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>e</td>
#       <td>1</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>e</td>
#       <td>2</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>e</td>
#       <td>3</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %%
df1.index = ["Maestro"]*len(df1)
df2.index = ["Julio"]*len(df2)
df3 = pd.concat([df1,df2])
df3
# Out:
#         clave  data  otro
# Maestro     b     0    17
# Maestro     b     1    27
# Maestro     a     2    15
# Maestro     c     3    28
# Maestro     a     4    24
# Maestro     a     5    22
# Maestro     b     6    12
# Julio       e     0    18
# Julio       e     1    25
# Julio       e     2    20
# Julio       e     3    10

# %%
df3.loc["Julio"]
# Out:
#       clave  data  otro
# Julio     e     0    18
# Julio     e     1    25
# Julio     e     2    20
# Julio     e     3    10

# %% [markdown]
# Si nos incomoda que el índice no sea consecutivo:

# %%
df3 = df3.reset_index(drop=True)
df3
# Out:
#    clave  data  otro
# 0      b     0    17
# 1      b     1    27
# 2      a     2    15
# 3      c     3    28
# 4      a     4    24
# 5      a     5    22
# 6      b     6    12
# 7      e     0    18
# 8      e     1    25
# 9      e     2    20
# 10     e     3    10

# %% [markdown]
# Sin embargo, hay veces que es útil usar el índice (si no tiene ya otro cometido) para "apuntar" el origen de cada fila

# %%
import IPython.display as display
import pandas as pd

df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['e', 'e', 'e', 'e'],
                 'data': range(4),
                 'otro': sample(range(10, 30), 4)})

df1.index = ["A"]*len(df1)
df2.index = ["B"]*len(df2)
display_side_by_side(df1,df2,pd.concat([df1,df2]),title="pd.concat([df1,df2])")
# Out:
# pd.concat([df1,df2])
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>29</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>1</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>2</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>3</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>1</td>
#       <td>28</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>2</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>3</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# **Ojo** porque `concat` no es tan *tonto* como parece; no se limita a pegar debajo sino que alinea por nombres de columna

# %%
import IPython.display as display
import pandas as pd

df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['e', 'e', 'e', 'e'],
                 'otro': sample(range(10, 30), 4),
                 'data': range(4) } )

df1.index = ["A"]*len(df1)
df2.index = ["B"]*len(df2)
display_side_by_side(df1,df2,pd.concat([df1,df2]), title="pd.concat([df1,df2])")
# Out:
# pd.concat([df1,df2])
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>24</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>otro</th>
#       <th>data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>26</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>29</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>11</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>27</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>0</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>1</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>2</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>c</td>
#       <td>3</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>4</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>a</td>
#       <td>5</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>b</td>
#       <td>6</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>0</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>1</td>
#       <td>29</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>2</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>e</td>
#       <td>3</td>
#       <td>27</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Con el parámetro axis (que por defecto vale 0) podemos hacer que en lugar de por filas concatene por columnas. En este caso lo lógico es que ambos dataframes tengan el mismo número de filas

# %%
import numpy as np
filas = 5
df1 = DataFrame({'A': np.random.randint(1,10,filas) ,
                 'B': np.random.randint(1,10,filas),
                 'C': np.random.randint(1,10,filas)})

df2 = DataFrame({'D': np.random.randint(2000,3000,filas),
                 'E': np.random.randint(2000,3000,filas)})
display_side_by_side(df1,df2, pd.concat([df1,df2],axis=1),
                     title="pd.concat([df1,df2],axis=1)")
# Out:
# pd.concat([df1,df2],axis=1)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8</td>
#       <td>5</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8</td>
#       <td>2</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2907</td>
#       <td>2842</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2493</td>
#       <td>2036</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2627</td>
#       <td>2532</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2160</td>
#       <td>2193</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2946</td>
#       <td>2613</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6</td>
#       <td>4</td>
#       <td>6</td>
#       <td>2907</td>
#       <td>2842</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>1</td>
#       <td>3</td>
#       <td>2493</td>
#       <td>2036</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>2</td>
#       <td>4</td>
#       <td>2627</td>
#       <td>2532</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8</td>
#       <td>5</td>
#       <td>8</td>
#       <td>2160</td>
#       <td>2193</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8</td>
#       <td>2</td>
#       <td>9</td>
#       <td>2946</td>
#       <td>2613</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Un aspecto muy importante: igual que al concatenar utiliza los nombres de columna aquí va a usar los números de fila

# %%
df2.index=[0,1,2,4,7]
display_side_by_side(df1,df2, pd.concat([df1,df2],axis=1),
                     title="pd.concat([df1,df2],axis=1)")
# Out:
# pd.concat([df1,df2],axis=1)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9</td>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8</td>
#       <td>5</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8</td>
#       <td>2</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2907</td>
#       <td>2842</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2493</td>
#       <td>2036</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2627</td>
#       <td>2532</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2160</td>
#       <td>2193</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2946</td>
#       <td>2613</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6.0</td>
#       <td>4.0</td>
#       <td>6.0</td>
#       <td>2907.0</td>
#       <td>2842.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>2493.0</td>
#       <td>2036.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>9.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>2627.0</td>
#       <td>2532.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8.0</td>
#       <td>5.0</td>
#       <td>8.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>8.0</td>
#       <td>2.0</td>
#       <td>9.0</td>
#       <td>2160.0</td>
#       <td>2193.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2946.0</td>
#       <td>2613.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Si el número de filas o columnas no encaja, `concat` añadirá valores vacío para completar

# %%
import numpy as np
filas = 5
df1 = DataFrame({'A': np.random.randint(1,10,filas) ,
                 'B': np.random.randint(1,10,filas),
                 'C': np.random.randint(1,10,filas)})

df2 = DataFrame({'D': np.random.randint(2000,3000,filas-1),
                 'E': np.random.randint(2000,3000,filas-1)})
display_side_by_side(df1,df2, pd.concat([df1,df2],axis=1),title="pd.concat([df1,df2],axis=1)")

display_side_by_side(df1,df2, pd.concat([df1,df2],axis=0),title="pd.concat([df1,df2],axis=0)")
# Out:
# pd.concat([df1,df2],axis=1)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8</td>
#       <td>7</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>8</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>7</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2325</td>
#       <td>2298</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2789</td>
#       <td>2808</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2944</td>
#       <td>2279</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2158</td>
#       <td>2909</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8</td>
#       <td>7</td>
#       <td>6</td>
#       <td>2325.0</td>
#       <td>2298.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>2789.0</td>
#       <td>2808.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>8</td>
#       <td>7</td>
#       <td>2944.0</td>
#       <td>2279.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>7</td>
#       <td>6</td>
#       <td>2158.0</td>
#       <td>2909.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>4</td>
#       <td>6</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table style="display:inline">
# pd.concat([df1,df2],axis=0)
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8</td>
#       <td>7</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>8</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>7</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2325</td>
#       <td>2298</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2789</td>
#       <td>2808</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2944</td>
#       <td>2279</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2158</td>
#       <td>2909</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.0</td>
#       <td>7.0</td>
#       <td>6.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.0</td>
#       <td>8.0</td>
#       <td>7.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>7.0</td>
#       <td>6.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.0</td>
#       <td>4.0</td>
#       <td>6.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2325.0</td>
#       <td>2298.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2789.0</td>
#       <td>2808.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2944.0</td>
#       <td>2279.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2158.0</td>
#       <td>2909.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# **Ejercicio**  El siguiente código descarga tres ficheros con datos diarios de metereología en Madrid y sus metadatos a una carpeta ./raw

# %%
import requests
from pathlib import Path
local = Path.cwd()
print(local)
carpeta_datos = Path(local,"raw")
print(carpeta_datos)
# Out:
# /content
# /content/raw

# %%
carpeta_datos.mkdir(exist_ok=True)

# %%
micarpeta = Path("/content/micarpeta/peliculas/accion/muerteYDestruccion")
print(micarpeta)
micarpeta.mkdir(parents=True)
# Out:
# /content/micarpeta/peliculas/accion/muerteYDestruccion

# %%
import requests
from pathlib import Path
local = Path.cwd()
print(local)
pathraw = Path(local,"raw")

pathraw.mkdir(exist_ok=True)

datos = ["https://datos.madrid.es/FWProjects/egob/Catalogo/MedioAmbiente/DatosMeteorologicos/Ficheros/Interpretaci%C3%B3n_datos_meteorologicos.pdf",
         "https://datos.madrid.es/egob/catalogo/300351-0-meteorologicos-diarios.csv",
         "https://datos.madrid.es/egob/catalogo/300351-3-meteorologicos-diarios.csv",
          "https://datos.madrid.es/egob/catalogo/300351-9-meteorologicos-diarios.csv",
         "https://datos.madrid.es/egob/catalogo/300351-12-meteorologicos-diarios.csv"]
locales = []
for url in datos:
    nombre = Path(url).name
    camino = Path(pathraw,nombre)
    r = requests.get(url, allow_redirects=True) # el fichero queda en la variable r
    if r.status_code==200:
        with open(camino, 'wb') as f:
            f.write(r.content) # ahora lo grabamos localmente
        print("Grabado,",camino)
        locales.append(camino)
    else:
        print("Error descargando ",url)
# Out:
# /content
# Grabado, /content/raw/Interpretaci%C3%B3n_datos_meteorologicos.pdf
# Grabado, /content/raw/300351-0-meteorologicos-diarios.csv
# Grabado, /content/raw/300351-3-meteorologicos-diarios.csv
# Grabado, /content/raw/300351-9-meteorologicos-diarios.csv
# Grabado, /content/raw/300351-12-meteorologicos-diarios.csv

# %%
locales
# Out:
# [PosixPath('/content/raw/Interpretaci%C3%B3n_datos_meteorologicos.pdf'),
#  PosixPath('/content/raw/300351-0-meteorologicos-diarios.csv'),
#  PosixPath('/content/raw/300351-3-meteorologicos-diarios.csv'),
#  PosixPath('/content/raw/300351-9-meteorologicos-diarios.csv')]

# %%
locales

# %% [markdown]
# Añadir código para combinar los 3 ficheros en uno solo sabiendo que tienen las mismas columnas y que sus caminos están en la variable `locales`

# %%
# primero leemos todos los ficheros; dfs será una lista de dataframes
dfs = []
for p in locales:
    if p.suffix==".csv":
        df_temp = pd.read_csv(p,sep=";")
        dfs.append(df_temp)

# %%
df = pd.concat(dfs)
df
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD  PUNTO_MUESTREO   ANO  MES  \
# 0            28         79       102        81  28079102_81_98  2019    1
# 1            28         79       102        81  28079102_81_98  2019    2
# 2            28         79       102        81  28079102_81_98  2019    3
# 3            28         79       102        81  28079102_81_98  2019    4
# 4            28         79       102        81  28079102_81_98  2019    5
# ...         ...        ...       ...       ...             ...   ...  ...
# 1119         28         79        59        89  28079059_89_98  2023    8
# 1120         28         79        59        89  28079059_89_98  2023    9
# 1121         28         79        59        89  28079059_89_98  2023   10
# 1122         28         79        59        89  28079059_89_98  2023   11
# 1123         28         79        59        89  28079059_89_98  2023   12
#
#         D01 V01   D02  ...   D27  V27   D28  V28   D29  V29    D30  V30   D31  \
# 0      0.66   V  1.16  ...  2.57    V  2.93    V  3.23    V   3.18    V  4.72
# 1      4.32   V  2.98  ...  1.36    V  0.97    V  0.00    N   0.00    N  0.00
# 2      1.57   V  1.13  ...  1.48    V  1.69    V  2.89    V   1.99    V  1.72
# 3      1.32   V  1.21  ...  1.00    V  1.82    V  1.97    V   1.84    V  0.00
# 4      2.06   V  2.21  ...  1.77    V  3.32    V  3.76    V   3.04    V  1.89
# ...     ...  ..   ...  ...   ...  ...   ...  ...   ...  ...    ...  ...   ...
# 1119   0.00   V  0.00  ...  0.00    V  0.00    V  0.00    V   0.00    V  0.00
# 1120   0.00   V  6.85  ...  0.00    V  0.00    V  0.00    V   0.00    V  0.00
# 1121   0.00   V  0.00  ...  0.00    V  0.00    V  1.80    V   3.00    V  0.00
# 1122   0.05   V  6.05  ...  0.00    V  0.00    V  0.00    V  13.60    V  0.00
# 1123  14.20   V  0.00  ...  0.00    V  0.00    V  0.00    V   0.00    V  0.00
#
#       V31
# 0       V
# 1       N
# 2       V
# 3       N
# 4       V
# ...   ...
# 1119    V
# 1120    N
# 1121    V
# 1122    N
# 1123    V
#
# [4279 rows x 69 columns]

# %%
df.MAGNITUD.unique()

# %% [markdown]
# <a name="Merge"></a>
# ### Merge
#
# En este caso se busca unir dos dataframes fijándonos en las coincidencias entre valores de dos columnas

# %%
from pandas import DataFrame
from pandas import Series
import pandas as pd
from random import sample
df1 = DataFrame({'clave': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                 'data1': range(7),
                 'otro': sample(range(10, 30), 7)})

df2 = DataFrame({'clave': ['a', 'b', 'b', 'd'],
                 'data2': range(4)})
display_side_by_side(df1,df2)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>29</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>d</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# Por defecto la mezcla es por la columna que se llama igual

# %%
display_side_by_side(df1,df2, pd.merge(df1,df2),title="pd.merge(df1,df2)")

# %% [markdown]
# Si no se indica lo contrario, `merge` busca columnas comunes y hace un (inner) 'join'. Nótese que en este caso no se tienen en cuenta los índices
# <br><br>
#
# El método merge se puede llamar también dentro de un dataframe (es equivalente)

# %%
df1.merge(df2)

# %% [markdown]
# También se pueden unir por varias columnas, que podemos especificar directamente con los parámetros `left_on`y `right_on`

# %%
df3 = df1.merge(df2, left_on=['clave','data1'], right_on = ['clave','data2'])

display_side_by_side(df1,df2, df3)

# %% [markdown]
# Si la clave o claves por las que querenos unir se llaman ambas igual podemos usar simplemente `on`

# %%
df3 = pd.merge(df1,df2,on='clave')
display_side_by_side(df1,df2, df3)

# %% [markdown]
# Además de *inner* join, se pueden hacer con el parámetro `how` tomando valores *left*, *right*, *outer*, *inner*
#
# <img src="https://www.golinuxcloud.com/wp-content/uploads/types_joins-1320x961.png">

# %% [markdown]
# En el caso de left, right y full/outer si la columna no encaja se rellenan con valores NaN

# %%
df3 = df1.merge( df2, on='clave', how='left')
display_side_by_side(df1,df2, df3)
# Out:
# &nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#       <td>2</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>c</td>
#       <td>3</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>4</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>a</td>
#       <td>5</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>b</td>
#       <td>6</td>
#       <td>29</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>d</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp;&nbsp;&nbsp;<table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>clave</th>
#       <th>data1</th>
#       <th>otro</th>
#       <th>data2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>b</td>
#       <td>0</td>
#       <td>16</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>b</td>
#       <td>0</td>
#       <td>16</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>b</td>
#       <td>1</td>
#       <td>13</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>a</td>
#       <td>2</td>
#       <td>27</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>c</td>
#       <td>3</td>
#       <td>20</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a</td>
#       <td>4</td>
#       <td>14</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>a</td>
#       <td>5</td>
#       <td>25</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>b</td>
#       <td>6</td>
#       <td>29</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>b</td>
#       <td>6</td>
#       <td>29</td>
#       <td>2.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline">

# %% [markdown]
# **Ejercicio** En
#
# https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/tweetsCompletadoOrdenRename.csv
#
# Tenemos datos de tweets, incluyendo el identificador del usuario que que ha emitidos cada tweet,  `userid`.
#
# En
#
# https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/usersrentaf.csv
#
# tenemos datos de usuarios: sú número de seguidores, la renta de la zona donde viven, etc. En este caso el identificador se llama simplemente `id`.
#
# Queremos unir ambos ficheros, de forma que a cada tweet se le añadan los datos de su usuario. Si un tweet no tiene su usario en el segundo conjunto de datos debemos borrarlo. Igualmente si un usuario no tiene ningún tweet no se incluirá.

# %%
import pandas as pd
url_tweets = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/tweetsCompletadoOrdenRename.csv"
url_users = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/usersrentaf.csv"
df_tweets = pd.read_csv(url_tweets)
df_users = pd.read_csv(url_users)

# %%
df_tweets.columns
# Out:
# Index(['userid', '_id', 'screen_name', 'text', 'hora', 'foto/vídeo', 'foto',
#        'video', ''¡'', ''!'', ''¿'', ''?'', 'menciones', 'hashtags', 'URLs',
#        'emojis', 'sentimiento medio emojis', 'palabras',
#        'proporción palabras correctas', 'longitud media palabras',
#        'mayúsculas', 'números', 'palabras vacías', 'adjetivos', 'sustantivos',
#        'verbos', 'tiempo pasado', 'tiempo presente', 'tiempo futuro',
#        'tiempo imperfecto', 'tiempo condicional', 'modo imperativo',
#        'modo indicativo', 'modo subjuntivo', 'primera persona',
#        'segunda persona', 'tercera persona', 'singular', 'plural',
#        'infinitivo', 'gerundio', 'participio', 'estoy en'],
#       dtype='object')

# %%
df_users.columns
# Out:
# Index(['id', 'screen_name', 'name', 'followers', 'created_at', 'friends_count',
#        'location', 'ntweets', 'verified', 'nTotal', 'tweets', 'localidad',
#        'provincia', 'distrito', 'seccion', 'cambio1518', 'mediana',
#        'rentapaismin', 'rentapaismax', 'rentacommin', 'rentacommax'],
#       dtype='object')

# %%
df3 = df_tweets.merge( df_users, left_on='userid', right_on='id', how='inner')
df3
# Out:
#                    userid                  _id    screen_name_x  \
# 0               372826254  1491110664240533504        heryartes
# 1               372826254  1491116058916184065        heryartes
# 2               372826254  1491121778416136202        heryartes
# 3               372826254  1448291132463587337        heryartes
# 4               372826254  1448294476733112321        heryartes
# ...                   ...                  ...              ...
# 92879          1069569979  1488472824272474117  gerson_iglesias
# 92880  840287644789723138  1488505529714581517     RococoDecora
# 92881          1974659378  1488541398982967296          sr_boca
# 92882          1553476147  1490968743136137217   MuchoFunkSpain
# 92883           272686602  1491027559001509888       EdixonTech
#
#                                                     text  hora  foto/vídeo  \
# 0      Dios siempre da por donde más le duele a uno. ...    18           0
# 1      Acaba de publicar un video en Telemicro https:...    18           1
# 2      Acaba de publicar un video https://t.co/wAwqtD...    18           1
# 3      Yo tenia varios días sin escuchar una emisora ...    14           0
# 4      Facebook lleno de puyas e indirectas, Twitter ...    14           0
# ...                                                  ...   ...         ...
# 92879  Acaba de publicar una foto en Oca Vila de Alla...    11           1
# 92880   Preciosidad para comedor https://t.co/vpPH5SLh5W    13           0
# 92881                   Merienda https://t.co/ID9gthKcB5    15           0
# 92882  Acaba de publicar una foto en Mucho Funk https...     8           1
# 92883                                  Mira @danigarrido    12           0
#
#        foto  video  '¡'  '!'  ...          localidad  provincia    distrito  \
# 0         0      0    0    0  ...      Soto del Real     Madrid          01
# 1         0      1    0    0  ...      Soto del Real     Madrid          01
# 2         0      1    0    0  ...      Soto del Real     Madrid          01
# 3         0      0    0    3  ...      Soto del Real     Madrid          01
# 4         0      0    1    1  ...      Soto del Real     Madrid          01
# ...     ...    ...  ...  ...  ...                ...        ...         ...
# 92879     1      0    0    0  ...            Allariz    Ourense          01
# 92880     0      0    0    0  ...                Teo   A Coruña          02
# 92881     0      0    0    0  ...          Barcelona  Barcelona    Eixample
# 92882     1      0    0    0  ...  Torrejón de Ardoz     Madrid          03
# 92883     0      0    0    0  ...             Madrid     Madrid  Arganzuela
#
#        seccion  cambio1518  mediana  rentapaismin  rentapaismax  rentacommin  \
# 0            1           9  17850.0            71            76           46
# 1            1           9  17850.0            71            76           46
# 2            1           9  17850.0            71            76           46
# 3            1           9  17850.0            71            76           46
# 4            1           9  17850.0            71            76           46
# ...        ...         ...      ...           ...           ...          ...
# 92879        1          11  14350.0            33            41           14
# 92880        2          16  15050.0            41            48           28
# 92881       85           9  24850.0            94            95           92
# 92882        8          15  16450.0            61            67           35
# 92883       83           7  20650.0            85            87           62
#
#        rentacommax
# 0               50
# 1               50
# 2               50
# 3               50
# 4               50
# ...            ...
# 92879           28
# 92880           44
# 92881           93
# 92882           40
# 92883           65
#
# [92884 rows x 64 columns]

# %%
df_tweets.shape,df_users.shape,df3.shape
# Out:
# ((92884, 43), (1287, 21), (92884, 64))

# %%
df3.columns
# Out:
# Index(['userid', '_id', 'screen_name_x', 'text', 'hora', 'foto/vídeo', 'foto',
#        'video', ''¡'', ''!'', ''¿'', ''?'', 'menciones', 'hashtags', 'URLs',
#        'emojis', 'sentimiento medio emojis', 'palabras',
#        'proporción palabras correctas', 'longitud media palabras',
#        'mayúsculas', 'números', 'palabras vacías', 'adjetivos', 'sustantivos',
#        'verbos', 'tiempo pasado', 'tiempo presente', 'tiempo futuro',
#        'tiempo imperfecto', 'tiempo condicional', 'modo imperativo',
#        'modo indicativo', 'modo subjuntivo', 'primera persona',
#        'segunda persona', 'tercera persona', 'singular', 'plural',
#        'infinitivo', 'gerundio', 'participio', 'estoy en', 'id',
#        'screen_name_y', 'name', 'followers', 'created_at', 'friends_count',
#        'location', 'ntweets', 'verified', 'nTotal', 'tweets', 'localidad',
#        'provincia', 'distrito', 'seccion', 'cambio1518', 'mediana',
#        'rentapaismin', 'rentapaismax', 'rentacommin', 'rentacommax'],
#       dtype='object')
